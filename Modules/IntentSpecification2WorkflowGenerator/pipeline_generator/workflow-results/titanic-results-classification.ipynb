# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Overall View

# %%
exp_results = pd.read_csv('titanic-result-comparison.csv')

exp_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 2                 2                       DT                 NaN
# 3                 3                       DT                 NaN
# 4                 4                      SVM        hypertangent
# ..              ...                      ...                 ...
# 71               71                      SVM                 rbf
# 72               72                      SVM                 rbf
# 73               73                      SVM                 rbf
# 74               74                      SVM                 rbf
# 75               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           78.26
# 1      random-relative                  NaN               NaN           82.12
# 2       first-absolute                  NaN               NaN           77.20
# 3       first-relative                  NaN               NaN           82.68
# 4      random-absolute                 drop           decimal           66.86
# ..                 ...                  ...               ...             ...
# 71      first-relative                 drop           min-max           72.22
# 72      first-relative                 drop           z-score           72.22
# 73      first-relative                 mean           decimal           69.27
# 74      first-relative                 mean           min-max           68.16
# 75      first-relative                 mean           z-score           64.25
#
#     balanced-accuracy-score  f1-score  optimized
# 0                     72.40    normal       True
# 1                     80.20    normal       True
# 2                     73.90    normal       True
# 3                     82.68    normal       True
# 4                     50.00  abnormal      False
# ..                      ...       ...        ...
# 71                    50.00  abnormal      False
# 72                    50.00  abnormal      False
# 73                    60.50    normal      False
# 74                    58.90    normal      False
# 75                    50.30    normal       True
#
# [76 rows x 10 columns]

# %%
exp_mean = exp_results['accuracy-score'].mean()
exp_min = exp_results['accuracy-score'].min()
exp_max = exp_results['accuracy-score'].max()

expb_mean = exp_results['balanced-accuracy-score'].mean()
expb_min = exp_results['balanced-accuracy-score'].min()
expb_max = exp_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {exp_mean}, Min: {exp_min}, Max: {exp_max}')
print(f'Experiment Stats -- Mean: {expb_mean}, Min: {expb_min}, Max: {expb_max}')
# Out:
# Experiment Stats -- Mean: 64.97934210526317, Min: 28.92, Max: 82.68
# Experiment Stats -- Mean: 54.63131578947368, Min: 32.6, Max: 82.68

# %%
exp_results = exp_results[~exp_results['f1-score'].isna()]

exp_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 2                 2                       DT                 NaN
# 3                 3                       DT                 NaN
# 4                 4                      SVM        hypertangent
# ..              ...                      ...                 ...
# 71               71                      SVM                 rbf
# 72               72                      SVM                 rbf
# 73               73                      SVM                 rbf
# 74               74                      SVM                 rbf
# 75               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           78.26
# 1      random-relative                  NaN               NaN           82.12
# 2       first-absolute                  NaN               NaN           77.20
# 3       first-relative                  NaN               NaN           82.68
# 4      random-absolute                 drop           decimal           66.86
# ..                 ...                  ...               ...             ...
# 71      first-relative                 drop           min-max           72.22
# 72      first-relative                 drop           z-score           72.22
# 73      first-relative                 mean           decimal           69.27
# 74      first-relative                 mean           min-max           68.16
# 75      first-relative                 mean           z-score           64.25
#
#     balanced-accuracy-score  f1-score  optimized
# 0                     72.40    normal       True
# 1                     80.20    normal       True
# 2                     73.90    normal       True
# 3                     82.68    normal       True
# 4                     50.00  abnormal      False
# ..                      ...       ...        ...
# 71                    50.00  abnormal      False
# 72                    50.00  abnormal      False
# 73                    60.50    normal      False
# 74                    58.90    normal      False
# 75                    50.30    normal       True
#
# [75 rows x 10 columns]

# %%
opt_results = exp_results[exp_results['optimized']==True]
opt_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 2                 2                       DT                 NaN
# 3                 3                       DT                 NaN
# 9                 9                      SVM        hypertangent
# 15               15                      SVM        hypertangent
# 21               21                      SVM        hypertangent
# 27               27                      SVM        hypertangent
# 33               33                      SVM          polynomial
# 39               39                      SVM          polynomial
# 45               45                      SVM          polynomial
# 51               51                      SVM          polynomial
# 57               57                      SVM                 rbf
# 63               63                      SVM                 rbf
# 69               69                      SVM                 rbf
# 75               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           78.26
# 1      random-relative                  NaN               NaN           82.12
# 2       first-absolute                  NaN               NaN           77.20
# 3       first-relative                  NaN               NaN           82.68
# 9      random-absolute                 mean           z-score           63.84
# 15     random-relative                 mean           z-score           54.19
# 21      first-absolute                 mean           z-score           60.94
# 27      first-relative                 mean           z-score           32.96
# 33     random-absolute                 mean           z-score           67.64
# 39     random-relative                 mean           z-score           71.51
# 45      first-absolute                 mean           z-score           61.82
# 51      first-relative                 mean           z-score           72.63
# 57     random-absolute                 mean           z-score           60.94
# 63     random-relative                 mean           z-score           56.42
# 69      first-absolute                 mean           z-score           61.95
# 75      first-relative                 mean           z-score           64.25
#
#     balanced-accuracy-score  f1-score  optimized
# 0                     72.40    normal       True
# 1                     80.20    normal       True
# 2                     73.90    normal       True
# 3                     82.68    normal       True
# 9                     57.60    normal       True
# 15                    49.40    normal       True
# 21                    49.20    normal       True
# 27                    32.60    normal       True
# 33                    64.20    normal       True
# 39                    68.00    normal       True
# 45                    50.00    normal       True
# 51                    68.60    normal       True
# 57                    49.70    normal       True
# 63                    48.50    normal       True
# 69                    50.00  abnormal       True
# 75                    50.30    normal       True

# %%
opt_mean = opt_results['accuracy-score'].mean()
opt_min = opt_results['accuracy-score'].min()
opt_max = opt_results['accuracy-score'].max()

optb_mean = opt_results['balanced-accuracy-score'].mean()
optb_min = opt_results['balanced-accuracy-score'].min()
optb_max = opt_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {opt_mean}, Min: {opt_min}, Max: {opt_max}')
print(f'Experiment Stats -- Mean: {optb_mean}, Min: {optb_min}, Max: {optb_max}')
# Out:
# Experiment Stats -- Mean: 65.584375, Min: 32.96, Max: 82.68
# Experiment Stats -- Mean: 59.205000000000005, Min: 32.6, Max: 82.68

# %%
dt_results = exp_results[exp_results['classification-algorithm']=="DT"]
dt_results
# Out:
#    workflow-number classification-algorithm algorithm-component  \
# 0                0                       DT                 NaN
# 1                1                       DT                 NaN
# 2                2                       DT                 NaN
# 3                3                       DT                 NaN
#
#   partition-component Imputation-component scaling-component  accuracy-score  \
# 0     random-absolute                  NaN               NaN           78.26
# 1     random-relative                  NaN               NaN           82.12
# 2      first-absolute                  NaN               NaN           77.20
# 3      first-relative                  NaN               NaN           82.68
#
#    balanced-accuracy-score f1-score  optimized
# 0                    72.40   normal       True
# 1                    80.20   normal       True
# 2                    73.90   normal       True
# 3                    82.68   normal       True

# %%
dt_mean = dt_results['accuracy-score'].mean()
dt_min = dt_results['accuracy-score'].min()
dt_max = dt_results['accuracy-score'].max()

dtb_mean = dt_results['balanced-accuracy-score'].mean()
dtb_min = dt_results['balanced-accuracy-score'].min()
dtb_max = dt_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {dt_mean}, Min: {dt_min}, Max: {dt_max}')
print(f'Experiment Stats -- Mean: {dtb_mean}, Min: {dtb_min}, Max: {dtb_max}')
# Out:
# Experiment Stats -- Mean: 80.065, Min: 77.2, Max: 82.68
# Experiment Stats -- Mean: 77.29500000000002, Min: 72.4, Max: 82.68

# %%
svm_results = exp_results[exp_results['classification-algorithm']=="SVM"]
svm_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 4                 4                      SVM        hypertangent
# 5                 5                      SVM        hypertangent
# 6                 6                      SVM        hypertangent
# 7                 7                      SVM        hypertangent
# 8                 8                      SVM        hypertangent
# ..              ...                      ...                 ...
# 71               71                      SVM                 rbf
# 72               72                      SVM                 rbf
# 73               73                      SVM                 rbf
# 74               74                      SVM                 rbf
# 75               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 4      random-absolute                 drop           decimal           66.86
# 5      random-absolute                 drop           min-max           67.70
# 6      random-absolute                 drop           z-score           66.67
# 7      random-absolute                 mean           decimal           61.82
# 8      random-absolute                 mean           min-max           61.82
# ..                 ...                  ...               ...             ...
# 71      first-relative                 drop           min-max           72.22
# 72      first-relative                 drop           z-score           72.22
# 73      first-relative                 mean           decimal           69.27
# 74      first-relative                 mean           min-max           68.16
# 75      first-relative                 mean           z-score           64.25
#
#     balanced-accuracy-score  f1-score  optimized
# 4                      50.0  abnormal      False
# 5                      50.0  abnormal      False
# 6                      50.0  abnormal      False
# 7                      50.0  abnormal      False
# 8                      50.0  abnormal      False
# ..                      ...       ...        ...
# 71                     50.0  abnormal      False
# 72                     50.0  abnormal      False
# 73                     60.5    normal      False
# 74                     58.9    normal      False
# 75                     50.3    normal       True
#
# [71 rows x 10 columns]

# %%
svm_mean = svm_results['accuracy-score'].mean()
svm_min = svm_results['accuracy-score'].min()
svm_max = svm_results['accuracy-score'].max()

svmb_mean = svm_results['balanced-accuracy-score'].mean()
svmb_min = svm_results['balanced-accuracy-score'].min()
svmb_max = svm_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {svm_mean}, Min: {svm_min}, Max: {svm_max}')
print(f'Experiment Stats -- Mean: {svmb_mean}, Min: {svmb_min}, Max: {svmb_max}')
# Out:
# Experiment Stats -- Mean: 64.11450704225354, Min: 28.92, Max: 75.42
# Experiment Stats -- Mean: 53.41971830985916, Min: 32.6, Max: 70.4

# %%
opt_svm_results = svm_results[svm_results['optimized']==True]
opt_svm_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 9                 9                      SVM        hypertangent
# 15               15                      SVM        hypertangent
# 21               21                      SVM        hypertangent
# 27               27                      SVM        hypertangent
# 33               33                      SVM          polynomial
# 39               39                      SVM          polynomial
# 45               45                      SVM          polynomial
# 51               51                      SVM          polynomial
# 57               57                      SVM                 rbf
# 63               63                      SVM                 rbf
# 69               69                      SVM                 rbf
# 75               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 9      random-absolute                 mean           z-score           63.84
# 15     random-relative                 mean           z-score           54.19
# 21      first-absolute                 mean           z-score           60.94
# 27      first-relative                 mean           z-score           32.96
# 33     random-absolute                 mean           z-score           67.64
# 39     random-relative                 mean           z-score           71.51
# 45      first-absolute                 mean           z-score           61.82
# 51      first-relative                 mean           z-score           72.63
# 57     random-absolute                 mean           z-score           60.94
# 63     random-relative                 mean           z-score           56.42
# 69      first-absolute                 mean           z-score           61.95
# 75      first-relative                 mean           z-score           64.25
#
#     balanced-accuracy-score  f1-score  optimized
# 9                      57.6    normal       True
# 15                     49.4    normal       True
# 21                     49.2    normal       True
# 27                     32.6    normal       True
# 33                     64.2    normal       True
# 39                     68.0    normal       True
# 45                     50.0    normal       True
# 51                     68.6    normal       True
# 57                     49.7    normal       True
# 63                     48.5    normal       True
# 69                     50.0  abnormal       True
# 75                     50.3    normal       True

# %%
opt_svm_mean = opt_svm_results['accuracy-score'].mean()
opt_svm_min = opt_svm_results['accuracy-score'].min()
opt_svm_max = opt_svm_results['accuracy-score'].max()

optb_svm_mean = opt_svm_results['balanced-accuracy-score'].mean()
optb_svm_min = opt_svm_results['balanced-accuracy-score'].min()
optb_svm_max = opt_svm_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {opt_svm_mean}, Min: {opt_svm_min}, Max: {opt_svm_max}')
print(f'Experiment Stats -- Mean: {optb_svm_mean}, Min: {optb_svm_min}, Max: {optb_svm_max}')
# Out:
# Experiment Stats -- Mean: 60.7575, Min: 32.96, Max: 72.63
# Experiment Stats -- Mean: 53.17499999999999, Min: 32.6, Max: 68.6

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Balanced Accuracy': (
        list(exp_results['balanced-accuracy-score']) +
        list(opt_results['balanced-accuracy-score']) +
        list(dt_results['balanced-accuracy-score']) +
        list(svm_results['balanced-accuracy-score']) +
        list(opt_svm_results['balanced-accuracy-score'])
    ),
    'Workflow Category': (
        ['All Workflows'] * len(exp_results['balanced-accuracy-score']) +
        ['Selected Workflows'] * len(opt_results['balanced-accuracy-score']) +
        ['DT Workflows'] * len(dt_results['balanced-accuracy-score']) +
        ['SVM Workflows'] * len(svm_results['balanced-accuracy-score']) +
        ['Selected SVM Workflows'] * len(opt_svm_results['balanced-accuracy-score'])
    )
}

df = pd.DataFrame(data)

sns.set_style("whitegrid")

plt.figure(figsize=(12, 7))
sns.boxplot(x='Workflow Category', y='Balanced Accuracy', data=df, palette="Set2")

plt.title('Balanced Accuracy Across Workflow Categories', fontsize=16, fontweight='bold')
plt.xlabel('Workflow Categories', fontsize=14)
plt.ylabel('Balanced Accuracy', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()
# Out:
# /tmp/ipykernel_980439/3082467574.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Workflow Category', y='Balanced Accuracy', data=df, palette="Set2")

# %% [markdown]
# # Overall View (with Eliminating Invalid Classifiers)

# %%
clean_exp_results = exp_results[exp_results['f1-score']=="normal"]

clean_exp_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 2                 2                       DT                 NaN
# 3                 3                       DT                 NaN
# 9                 9                      SVM        hypertangent
# 14               14                      SVM        hypertangent
# 15               15                      SVM        hypertangent
# 18               18                      SVM        hypertangent
# 21               21                      SVM        hypertangent
# 24               24                      SVM        hypertangent
# 26               26                      SVM        hypertangent
# 27               27                      SVM        hypertangent
# 29               29                      SVM          polynomial
# 30               30                      SVM          polynomial
# 33               33                      SVM          polynomial
# 36               36                      SVM          polynomial
# 37               37                      SVM          polynomial
# 38               38                      SVM          polynomial
# 39               39                      SVM          polynomial
# 40               40                      SVM          polynomial
# 41               41                      SVM          polynomial
# 42               42                      SVM          polynomial
# 44               44                      SVM          polynomial
# 45               45                      SVM          polynomial
# 49               49                      SVM          polynomial
# 50               50                      SVM          polynomial
# 51               51                      SVM          polynomial
# 53               53                      SVM                 rbf
# 55               55                      SVM                 rbf
# 56               56                      SVM                 rbf
# 57               57                      SVM                 rbf
# 58               58                      SVM                 rbf
# 59               59                      SVM                 rbf
# 61               61                      SVM                 rbf
# 62               62                      SVM                 rbf
# 63               63                      SVM                 rbf
# 73               73                      SVM                 rbf
# 74               74                      SVM                 rbf
# 75               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           78.26
# 1      random-relative                  NaN               NaN           82.12
# 2       first-absolute                  NaN               NaN           77.20
# 3       first-relative                  NaN               NaN           82.68
# 9      random-absolute                 mean           z-score           63.84
# 14     random-relative                 mean           min-max           67.04
# 15     random-relative                 mean           z-score           54.19
# 18      first-absolute                 drop           z-score           28.92
# 21      first-absolute                 mean           z-score           60.94
# 24      first-relative                 drop           z-score           75.00
# 26      first-relative                 mean           min-max           73.74
# 27      first-relative                 mean           z-score           32.96
# 29     random-absolute                 drop           min-max           66.25
# 30     random-absolute                 drop           z-score           49.40
# 33     random-absolute                 mean           z-score           67.64
# 36     random-relative                 drop           z-score           71.79
# 37     random-relative                 mean           decimal           67.04
# 38     random-relative                 mean           min-max           69.83
# 39     random-relative                 mean           z-score           71.51
# 40      first-absolute                 drop           decimal           30.12
# 41      first-absolute                 drop           min-max           32.53
# 42      first-absolute                 drop           z-score           31.93
# 44      first-absolute                 mean           min-max           63.50
# 45      first-absolute                 mean           z-score           61.82
# 49      first-relative                 mean           decimal           75.42
# 50      first-relative                 mean           min-max           74.86
# 51      first-relative                 mean           z-score           72.63
# 53     random-absolute                 drop           min-max           67.07
# 55     random-absolute                 mean           decimal           67.00
# 56     random-absolute                 mean           min-max           58.91
# 57     random-absolute                 mean           z-score           60.94
# 58     random-relative                 drop           decimal           72.73
# 59     random-relative                 drop           min-max           65.96
# 61     random-relative                 mean           decimal           75.40
# 62     random-relative                 mean           min-max           70.95
# 63     random-relative                 mean           z-score           56.42
# 73      first-relative                 mean           decimal           69.27
# 74      first-relative                 mean           min-max           68.16
# 75      first-relative                 mean           z-score           64.25
#
#     balanced-accuracy-score f1-score  optimized
# 0                     72.40   normal       True
# 1                     80.20   normal       True
# 2                     73.90   normal       True
# 3                     82.68   normal       True
# 9                     57.60   normal       True
# 14                    61.00   normal      False
# 15                    49.40   normal       True
# 18                    40.30   normal      False
# 21                    49.20   normal       True
# 24                    55.00   normal      False
# 26                    67.40   normal      False
# 27                    32.60   normal       True
# 29                    58.00   normal      False
# 30                    51.30   normal      False
# 33                    64.20   normal       True
# 36                    63.40   normal      False
# 37                    59.60   normal      False
# 38                    66.00   normal      False
# 39                    68.00   normal       True
# 40                    44.70   normal      False
# 41                    48.90   normal      False
# 42                    49.00   normal      False
# 44                    53.10   normal      False
# 45                    50.00   normal       True
# 49                    69.40   normal      False
# 50                    70.40   normal      False
# 51                    68.60   normal       True
# 53                    52.20   normal      False
# 55                    62.20   normal      False
# 56                    51.90   normal      False
# 57                    49.70   normal       True
# 58                    56.60   normal      False
# 59                    53.70   normal      False
# 61                    70.40   normal      False
# 62                    67.10   normal      False
# 63                    48.50   normal       True
# 73                    60.50   normal      False
# 74                    58.90   normal      False
# 75                    50.30   normal       True

# %%
clean_exp_mean = clean_exp_results['accuracy-score'].mean()
clean_exp_min = clean_exp_results['accuracy-score'].min()
clean_exp_max = clean_exp_results['accuracy-score'].max()

clean_expb_mean = clean_exp_results['balanced-accuracy-score'].mean()
clean_expb_min = clean_exp_results['balanced-accuracy-score'].min()
clean_expb_max = clean_exp_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {clean_exp_mean}, Min: {clean_exp_min}, Max: {clean_exp_max}')
print(f'Experiment Stats -- Mean: {clean_expb_mean}, Min: {clean_expb_min}, Max: {clean_expb_max}')
print(f'Dimensions: {clean_exp_results.shape}')
# Out:
# Experiment Stats -- Mean: 63.59538461538461, Min: 28.92, Max: 82.68
# Experiment Stats -- Mean: 58.673846153846156, Min: 32.6, Max: 82.68
# Dimensions: (39, 10)

# %%
clean_opt_results = clean_exp_results[clean_exp_results['optimized']==True]
clean_opt_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 2                 2                       DT                 NaN
# 3                 3                       DT                 NaN
# 9                 9                      SVM        hypertangent
# 15               15                      SVM        hypertangent
# 21               21                      SVM        hypertangent
# 27               27                      SVM        hypertangent
# 33               33                      SVM          polynomial
# 39               39                      SVM          polynomial
# 45               45                      SVM          polynomial
# 51               51                      SVM          polynomial
# 57               57                      SVM                 rbf
# 63               63                      SVM                 rbf
# 75               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           78.26
# 1      random-relative                  NaN               NaN           82.12
# 2       first-absolute                  NaN               NaN           77.20
# 3       first-relative                  NaN               NaN           82.68
# 9      random-absolute                 mean           z-score           63.84
# 15     random-relative                 mean           z-score           54.19
# 21      first-absolute                 mean           z-score           60.94
# 27      first-relative                 mean           z-score           32.96
# 33     random-absolute                 mean           z-score           67.64
# 39     random-relative                 mean           z-score           71.51
# 45      first-absolute                 mean           z-score           61.82
# 51      first-relative                 mean           z-score           72.63
# 57     random-absolute                 mean           z-score           60.94
# 63     random-relative                 mean           z-score           56.42
# 75      first-relative                 mean           z-score           64.25
#
#     balanced-accuracy-score f1-score  optimized
# 0                     72.40   normal       True
# 1                     80.20   normal       True
# 2                     73.90   normal       True
# 3                     82.68   normal       True
# 9                     57.60   normal       True
# 15                    49.40   normal       True
# 21                    49.20   normal       True
# 27                    32.60   normal       True
# 33                    64.20   normal       True
# 39                    68.00   normal       True
# 45                    50.00   normal       True
# 51                    68.60   normal       True
# 57                    49.70   normal       True
# 63                    48.50   normal       True
# 75                    50.30   normal       True

# %%
clean_opt_mean = clean_opt_results['accuracy-score'].mean()
clean_opt_min = clean_opt_results['accuracy-score'].min()
clean_opt_max = clean_opt_results['accuracy-score'].max()

clean_optb_mean = clean_opt_results['balanced-accuracy-score'].mean()
clean_optb_min = clean_opt_results['balanced-accuracy-score'].min()
clean_optb_max = clean_opt_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {clean_opt_mean}, Min: {clean_opt_min}, Max: {clean_opt_max}')
print(f'Experiment Stats -- Mean: {clean_optb_mean}, Min: {clean_optb_min}, Max: {clean_optb_max}')
print(f'Dimensions: {clean_opt_results.shape}')
# Out:
# Experiment Stats -- Mean: 65.82666666666667, Min: 32.96, Max: 82.68
# Experiment Stats -- Mean: 59.81866666666667, Min: 32.6, Max: 82.68
# Dimensions: (15, 10)

# %%
clean_svm_results = clean_exp_results[clean_exp_results['classification-algorithm']=="SVM"]
clean_svm_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 9                 9                      SVM        hypertangent
# 14               14                      SVM        hypertangent
# 15               15                      SVM        hypertangent
# 18               18                      SVM        hypertangent
# 21               21                      SVM        hypertangent
# 24               24                      SVM        hypertangent
# 26               26                      SVM        hypertangent
# 27               27                      SVM        hypertangent
# 29               29                      SVM          polynomial
# 30               30                      SVM          polynomial
# 33               33                      SVM          polynomial
# 36               36                      SVM          polynomial
# 37               37                      SVM          polynomial
# 38               38                      SVM          polynomial
# 39               39                      SVM          polynomial
# 40               40                      SVM          polynomial
# 41               41                      SVM          polynomial
# 42               42                      SVM          polynomial
# 44               44                      SVM          polynomial
# 45               45                      SVM          polynomial
# 49               49                      SVM          polynomial
# 50               50                      SVM          polynomial
# 51               51                      SVM          polynomial
# 53               53                      SVM                 rbf
# 55               55                      SVM                 rbf
# 56               56                      SVM                 rbf
# 57               57                      SVM                 rbf
# 58               58                      SVM                 rbf
# 59               59                      SVM                 rbf
# 61               61                      SVM                 rbf
# 62               62                      SVM                 rbf
# 63               63                      SVM                 rbf
# 73               73                      SVM                 rbf
# 74               74                      SVM                 rbf
# 75               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 9      random-absolute                 mean           z-score           63.84
# 14     random-relative                 mean           min-max           67.04
# 15     random-relative                 mean           z-score           54.19
# 18      first-absolute                 drop           z-score           28.92
# 21      first-absolute                 mean           z-score           60.94
# 24      first-relative                 drop           z-score           75.00
# 26      first-relative                 mean           min-max           73.74
# 27      first-relative                 mean           z-score           32.96
# 29     random-absolute                 drop           min-max           66.25
# 30     random-absolute                 drop           z-score           49.40
# 33     random-absolute                 mean           z-score           67.64
# 36     random-relative                 drop           z-score           71.79
# 37     random-relative                 mean           decimal           67.04
# 38     random-relative                 mean           min-max           69.83
# 39     random-relative                 mean           z-score           71.51
# 40      first-absolute                 drop           decimal           30.12
# 41      first-absolute                 drop           min-max           32.53
# 42      first-absolute                 drop           z-score           31.93
# 44      first-absolute                 mean           min-max           63.50
# 45      first-absolute                 mean           z-score           61.82
# 49      first-relative                 mean           decimal           75.42
# 50      first-relative                 mean           min-max           74.86
# 51      first-relative                 mean           z-score           72.63
# 53     random-absolute                 drop           min-max           67.07
# 55     random-absolute                 mean           decimal           67.00
# 56     random-absolute                 mean           min-max           58.91
# 57     random-absolute                 mean           z-score           60.94
# 58     random-relative                 drop           decimal           72.73
# 59     random-relative                 drop           min-max           65.96
# 61     random-relative                 mean           decimal           75.40
# 62     random-relative                 mean           min-max           70.95
# 63     random-relative                 mean           z-score           56.42
# 73      first-relative                 mean           decimal           69.27
# 74      first-relative                 mean           min-max           68.16
# 75      first-relative                 mean           z-score           64.25
#
#     balanced-accuracy-score f1-score  optimized
# 9                      57.6   normal       True
# 14                     61.0   normal      False
# 15                     49.4   normal       True
# 18                     40.3   normal      False
# 21                     49.2   normal       True
# 24                     55.0   normal      False
# 26                     67.4   normal      False
# 27                     32.6   normal       True
# 29                     58.0   normal      False
# 30                     51.3   normal      False
# 33                     64.2   normal       True
# 36                     63.4   normal      False
# 37                     59.6   normal      False
# 38                     66.0   normal      False
# 39                     68.0   normal       True
# 40                     44.7   normal      False
# 41                     48.9   normal      False
# 42                     49.0   normal      False
# 44                     53.1   normal      False
# 45                     50.0   normal       True
# 49                     69.4   normal      False
# 50                     70.4   normal      False
# 51                     68.6   normal       True
# 53                     52.2   normal      False
# 55                     62.2   normal      False
# 56                     51.9   normal      False
# 57                     49.7   normal       True
# 58                     56.6   normal      False
# 59                     53.7   normal      False
# 61                     70.4   normal      False
# 62                     67.1   normal      False
# 63                     48.5   normal       True
# 73                     60.5   normal      False
# 74                     58.9   normal      False
# 75                     50.3   normal       True

# %%
grouped_df = clean_svm_results.groupby(['Imputation-component']).count()
grouped_df
# Out:
#                       workflow-number  classification-algorithm  \
# Imputation-component
# drop                               11                        11
# mean                               24                        24
#
#                       algorithm-component  partition-component  \
# Imputation-component
# drop                                   11                   11
# mean                                   24                   24
#
#                       scaling-component  accuracy-score  \
# Imputation-component
# drop                                 11              11
# mean                                 24              24
#
#                       balanced-accuracy-score  f1-score  optimized
# Imputation-component
# drop                                       11        11         11
# mean                                       24        24         24

# %%
grouped_df_2 = clean_svm_results.groupby(['Imputation-component'])['balanced-accuracy-score'].mean()
grouped_df_2
# Out:
# Imputation-component
# drop    52.100000
# mean    58.583333
# Name: balanced-accuracy-score, dtype: float64

# %%
grouped_df_3 = clean_svm_results.groupby(['scaling-component']).count()
grouped_df_3
# Out:
#                    workflow-number  classification-algorithm  \
# scaling-component
# decimal                          7                         7
# min-max                         12                        12
# z-score                         16                        16
#
#                    algorithm-component  partition-component  \
# scaling-component
# decimal                              7                    7
# min-max                             12                   12
# z-score                             16                   16
#
#                    Imputation-component  accuracy-score  \
# scaling-component
# decimal                               7               7
# min-max                              12              12
# z-score                              16              16
#
#                    balanced-accuracy-score  f1-score  optimized
# scaling-component
# decimal                                  7         7          7
# min-max                                 12        12         12
# z-score                                 16        16         16

# %%
grouped_df_4 = clean_svm_results.groupby(['scaling-component'])['balanced-accuracy-score'].mean()
grouped_df_4
# Out:
# scaling-component
# decimal    60.485714
# min-max    59.050000
# z-score    52.943750
# Name: balanced-accuracy-score, dtype: float64

# %%
grouped_df_4 = clean_svm_results.groupby(['optimized'])['balanced-accuracy-score'].mean()
grouped_df_4
# Out:
# optimized
# False    57.958333
# True     53.463636
# Name: balanced-accuracy-score, dtype: float64

# %%
clean_svm_mean = clean_svm_results['accuracy-score'].mean()
clean_svm_min = clean_svm_results['accuracy-score'].min()
clean_svm_max = clean_svm_results['accuracy-score'].max()

clean_svmb_mean = clean_svm_results['balanced-accuracy-score'].mean()
clean_svmb_min = clean_svm_results['balanced-accuracy-score'].min()
clean_svmb_max = clean_svm_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {clean_svm_mean}, Min: {clean_svm_min}, Max: {clean_svm_max}')
print(f'Experiment Stats -- Mean: {clean_svmb_mean}, Min: {clean_svmb_min}, Max: {clean_svmb_max}')
print(f'Dimensions: {clean_svm_results.shape}')
# Out:
# Experiment Stats -- Mean: 61.71314285714285, Min: 28.92, Max: 75.42
# Experiment Stats -- Mean: 56.54571428571429, Min: 32.6, Max: 70.4
# Dimensions: (35, 10)

# %%
clean_opt_svm_results = clean_svm_results[clean_svm_results['optimized']==True]
clean_opt_svm_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 9                 9                      SVM        hypertangent
# 15               15                      SVM        hypertangent
# 21               21                      SVM        hypertangent
# 27               27                      SVM        hypertangent
# 33               33                      SVM          polynomial
# 39               39                      SVM          polynomial
# 45               45                      SVM          polynomial
# 51               51                      SVM          polynomial
# 57               57                      SVM                 rbf
# 63               63                      SVM                 rbf
# 75               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 9      random-absolute                 mean           z-score           63.84
# 15     random-relative                 mean           z-score           54.19
# 21      first-absolute                 mean           z-score           60.94
# 27      first-relative                 mean           z-score           32.96
# 33     random-absolute                 mean           z-score           67.64
# 39     random-relative                 mean           z-score           71.51
# 45      first-absolute                 mean           z-score           61.82
# 51      first-relative                 mean           z-score           72.63
# 57     random-absolute                 mean           z-score           60.94
# 63     random-relative                 mean           z-score           56.42
# 75      first-relative                 mean           z-score           64.25
#
#     balanced-accuracy-score f1-score  optimized
# 9                      57.6   normal       True
# 15                     49.4   normal       True
# 21                     49.2   normal       True
# 27                     32.6   normal       True
# 33                     64.2   normal       True
# 39                     68.0   normal       True
# 45                     50.0   normal       True
# 51                     68.6   normal       True
# 57                     49.7   normal       True
# 63                     48.5   normal       True
# 75                     50.3   normal       True

# %%
clean_opt_svm_mean = clean_opt_svm_results['accuracy-score'].mean()
clean_opt_svm_min = clean_opt_svm_results['accuracy-score'].min()
clean_opt_svm_max = clean_opt_svm_results['accuracy-score'].max()

clean_optb_svm_mean = clean_opt_svm_results['balanced-accuracy-score'].mean()
clean_optb_svm_min = clean_opt_svm_results['balanced-accuracy-score'].min()
clean_optb_svm_max = clean_opt_svm_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {clean_opt_svm_mean}, Min: {clean_opt_svm_min}, Max: {clean_opt_svm_max}')
print(f'Experiment Stats -- Mean: {clean_optb_svm_mean}, Min: {clean_optb_svm_min}, Max: {clean_optb_svm_max}')
print(f'Dimensions: {clean_opt_svm_results.shape}')
# Out:
# Experiment Stats -- Mean: 60.64909090909091, Min: 32.96, Max: 72.63
# Experiment Stats -- Mean: 53.463636363636354, Min: 32.6, Max: 68.6
# Dimensions: (11, 10)

# %%
grouped_df_5 = clean_svm_results.groupby(['partition-component','Imputation-component','scaling-component'])['balanced-accuracy-score'].mean()
grouped_df_5
# Out:
# partition-component  Imputation-component  scaling-component
# first-absolute       drop                  decimal              44.700000
#                                            min-max              48.900000
#                                            z-score              44.650000
#                      mean                  min-max              53.100000
#                                            z-score              49.600000
# first-relative       drop                  z-score              55.000000
#                      mean                  decimal              64.950000
#                                            min-max              65.566667
#                                            z-score              50.500000
# random-absolute      drop                  min-max              55.100000
#                                            z-score              51.300000
#                      mean                  decimal              62.200000
#                                            min-max              51.900000
#                                            z-score              57.166667
# random-relative      drop                  decimal              56.600000
#                                            min-max              53.700000
#                                            z-score              63.400000
#                      mean                  decimal              65.000000
#                                            min-max              64.700000
#                                            z-score              55.300000
# Name: balanced-accuracy-score, dtype: float64

# %%
grouped_df_6 = clean_opt_svm_results.groupby(['partition-component','Imputation-component','scaling-component'])['balanced-accuracy-score'].mean()
grouped_df_6
# Out:
# partition-component  Imputation-component  scaling-component
# first-absolute       mean                  z-score              49.600000
# first-relative       mean                  z-score              50.500000
# random-absolute      mean                  z-score              57.166667
# random-relative      mean                  z-score              55.300000
# Name: balanced-accuracy-score, dtype: float64

# %%
data = {
    'Balanced Accuracy': (
        list(clean_exp_results['balanced-accuracy-score']) +
        list(clean_opt_results['balanced-accuracy-score']) +
        list(dt_results['balanced-accuracy-score']) +
        list(clean_svm_results['balanced-accuracy-score']) +
        list(clean_opt_svm_results['balanced-accuracy-score'])
    ),
    'Workflow Category': (
        ['All Workflows'] * len(clean_exp_results['balanced-accuracy-score']) +
        ['Selected Workflows'] * len(clean_opt_results['balanced-accuracy-score']) +
        ['DT Workflows'] * len(dt_results['balanced-accuracy-score']) +
        ['SVM Workflows'] * len(clean_svm_results['balanced-accuracy-score']) +
        ['Selected SVM Workflows'] * len(clean_opt_svm_results['balanced-accuracy-score'])
    )
}

df = pd.DataFrame(data)

sns.set_style("whitegrid")

plt.figure(figsize=(12, 7))
sns.boxplot(x='Workflow Category', y='Balanced Accuracy', data=df, palette="Set2")

plt.title('Balanced Accuracy Across Valid Workflow Categories', fontsize=16, fontweight='bold')
plt.xlabel('Workflow Categories', fontsize=14)
plt.ylabel('Balanced Accuracy', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
# Out:
# /tmp/ipykernel_980439/4108620472.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Workflow Category', y='Balanced Accuracy', data=df, palette="Set2")
# (array([30., 40., 50., 60., 70., 80., 90.]),
#  [Text(0, 30.0, '30'),
#   Text(0, 40.0, '40'),
#   Text(0, 50.0, '50'),
#   Text(0, 60.0, '60'),
#   Text(0, 70.0, '70'),
#   Text(0, 80.0, '80'),
#   Text(0, 90.0, '90')])
