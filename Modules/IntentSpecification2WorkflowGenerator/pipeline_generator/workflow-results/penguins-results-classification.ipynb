# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Overall View

# %%
exp_results = pd.read_csv('penguins-result-comparison.csv')

exp_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 2                 2                       DT                 NaN
# 3                 3                       DT                 NaN
# 4                 4                      SVM        hypertangent
# ..              ...                      ...                 ...
# 71               71                      SVM                 rbf
# 72               72                      SVM                 rbf
# 73               73                      SVM                 rbf
# 74               74                      SVM                 rbf
# 75               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           93.03
# 1      random-relative                  NaN               NaN           94.20
# 2       first-absolute                  NaN               NaN           21.31
# 3       first-relative                  NaN               NaN           97.10
# 4      random-absolute                 drop           decimal           40.80
# ..                 ...                  ...               ...             ...
# 71      first-relative                 drop           min-max          100.00
# 72      first-relative                 drop           z-score            3.03
# 73      first-relative                 mean           decimal           98.55
# 74      first-relative                 mean           min-max           98.55
# 75      first-relative                 mean           z-score            2.90
#
#     balanced-accuracy-score  f1-score  optimized reason
# 0                     93.03    normal       True    NaN
# 1                     93.60    normal       True    NaN
# 2                      0.50  abnormal       True    NaN
# 3                      0.00  abnormal       True    NaN
# 4                      0.50  abnormal      False    NaN
# ..                      ...       ...        ...    ...
# 71                     0.00  abnormal      False    NaN
# 72                     0.00  abnormal       True    NaN
# 73                     0.00  abnormal      False    NaN
# 74                     0.00  abnormal      False    NaN
# 75                     0.00  abnormal      False    NaN
#
# [76 rows x 11 columns]

# %%
exp_results = exp_results[~exp_results['f1-score'].isna()]

exp_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 2                 2                       DT                 NaN
# 3                 3                       DT                 NaN
# 4                 4                      SVM        hypertangent
# 5                 5                      SVM        hypertangent
# 6                 6                      SVM        hypertangent
# 7                 7                      SVM        hypertangent
# 8                 8                      SVM        hypertangent
# 9                 9                      SVM        hypertangent
# 10               10                      SVM        hypertangent
# 11               11                      SVM        hypertangent
# 12               12                      SVM        hypertangent
# 13               13                      SVM        hypertangent
# 14               14                      SVM        hypertangent
# 15               15                      SVM        hypertangent
# 22               22                      SVM        hypertangent
# 23               23                      SVM        hypertangent
# 24               24                      SVM        hypertangent
# 25               25                      SVM        hypertangent
# 26               26                      SVM        hypertangent
# 27               27                      SVM        hypertangent
# 28               28                      SVM          polynomial
# 29               29                      SVM          polynomial
# 30               30                      SVM          polynomial
# 31               31                      SVM          polynomial
# 32               32                      SVM          polynomial
# 33               33                      SVM          polynomial
# 34               34                      SVM          polynomial
# 35               35                      SVM          polynomial
# 36               36                      SVM          polynomial
# 37               37                      SVM          polynomial
# 38               38                      SVM          polynomial
# 39               39                      SVM          polynomial
# 46               46                      SVM          polynomial
# 47               47                      SVM          polynomial
# 48               48                      SVM          polynomial
# 49               49                      SVM          polynomial
# 50               50                      SVM          polynomial
# 51               51                      SVM          polynomial
# 52               52                      SVM                 rbf
# 53               53                      SVM                 rbf
# 54               54                      SVM                 rbf
# 55               55                      SVM                 rbf
# 56               56                      SVM                 rbf
# 57               57                      SVM                 rbf
# 58               58                      SVM                 rbf
# 59               59                      SVM                 rbf
# 60               60                      SVM                 rbf
# 61               61                      SVM                 rbf
# 62               62                      SVM                 rbf
# 63               63                      SVM                 rbf
# 70               70                      SVM                 rbf
# 71               71                      SVM                 rbf
# 72               72                      SVM                 rbf
# 73               73                      SVM                 rbf
# 74               74                      SVM                 rbf
# 75               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           93.03
# 1      random-relative                  NaN               NaN           94.20
# 2       first-absolute                  NaN               NaN           21.31
# 3       first-relative                  NaN               NaN           97.10
# 4      random-absolute                 drop           decimal           40.80
# 5      random-absolute                 drop           min-max            0.80
# 6      random-absolute                 drop           z-score           94.94
# 7      random-absolute                 mean           decimal           74.59
# 8      random-absolute                 mean           min-max           78.69
# 9      random-absolute                 mean           z-score           93.03
# 10     random-relative                 drop           decimal           76.81
# 11     random-relative                 drop           min-max           82.80
# 12     random-relative                 drop           z-score           97.10
# 13     random-relative                 mean           decimal           81.16
# 14     random-relative                 mean           min-max           78.26
# 15     random-relative                 mean           z-score           88.40
# 22      first-relative                 drop           decimal            0.00
# 23      first-relative                 drop           min-max          100.00
# 24      first-relative                 drop           z-score           63.64
# 25      first-relative                 mean           decimal            0.00
# 26      first-relative                 mean           min-max           98.55
# 27      first-relative                 mean           z-score           63.77
# 28     random-absolute                 drop           decimal           68.49
# 29     random-absolute                 drop           min-max           96.64
# 30     random-absolute                 drop           z-score           97.91
# 31     random-absolute                 mean           decimal           78.69
# 32     random-absolute                 mean           min-max           97.95
# 33     random-absolute                 mean           z-score           96.72
# 34     random-relative                 drop           decimal           81.82
# 35     random-relative                 drop           min-max           98.51
# 36     random-relative                 drop           z-score           98.53
# 37     random-relative                 mean           decimal           76.81
# 38     random-relative                 mean           min-max           97.10
# 39     random-relative                 mean           z-score          100.00
# 46      first-relative                 drop           decimal           66.67
# 47      first-relative                 drop           min-max          100.00
# 48      first-relative                 drop           z-score          100.00
# 49      first-relative                 mean           decimal           62.32
# 50      first-relative                 mean           min-max           98.55
# 51      first-relative                 mean           z-score           98.55
# 52     random-absolute                 drop           decimal           98.31
# 53     random-absolute                 drop           min-max           91.21
# 54     random-absolute                 drop           z-score           42.13
# 55     random-absolute                 mean           decimal           98.36
# 56     random-absolute                 mean           min-max           94.26
# 57     random-absolute                 mean           z-score           42.21
# 58     random-relative                 drop           decimal          100.00
# 59     random-relative                 drop           min-max           95.38
# 60     random-relative                 drop           z-score           46.38
# 61     random-relative                 mean           decimal           97.10
# 62     random-relative                 mean           min-max           98.55
# 63     random-relative                 mean           z-score           39.13
# 70      first-relative                 drop           decimal          100.00
# 71      first-relative                 drop           min-max          100.00
# 72      first-relative                 drop           z-score            3.03
# 73      first-relative                 mean           decimal           98.55
# 74      first-relative                 mean           min-max           98.55
# 75      first-relative                 mean           z-score            2.90
#
#     balanced-accuracy-score  f1-score  optimized reason
# 0                     93.03    normal       True    NaN
# 1                     93.60    normal       True    NaN
# 2                      0.50  abnormal       True    NaN
# 3                      0.00  abnormal       True    NaN
# 4                      0.50  abnormal      False    NaN
# 5                     77.30  abnormal      False    NaN
# 6                     94.40    normal       True    NaN
# 7                     75.20    normal      False    NaN
# 8                     76.90  abnormal      False    NaN
# 9                     92.50    normal      False    NaN
# 10                    75.20  abnormal      False    NaN
# 11                    77.90  abnormal      False    NaN
# 12                    97.70    normal       True    NaN
# 13                    76.10  abnormal      False    NaN
# 14                    76.90  abnormal      False    NaN
# 15                    89.20    normal      False    NaN
# 22                     0.00  abnormal      False    NaN
# 23                     0.00  abnormal      False    NaN
# 24                     0.00  abnormal       True    NaN
# 25                     0.00  abnormal      False    NaN
# 26                     0.00  abnormal      False    NaN
# 27                     0.00  abnormal      False    NaN
# 28                    70.70  abnormal      False    NaN
# 29                    96.20    normal      False    NaN
# 30                    97.60    normal       True    NaN
# 31                    77.20    normal      False    NaN
# 32                    97.90    normal      False    NaN
# 33                    97.20    normal      False    NaN
# 34                    78.00    normal      False    NaN
# 35                    98.00    normal      False    NaN
# 36                    99.20    normal       True    NaN
# 37                    76.30    normal      False    NaN
# 38                    97.00    normal      False    NaN
# 39                   100.00    normal      False    NaN
# 46                     0.00  abnormal      False    NaN
# 47                     0.00  abnormal      False    NaN
# 48                     0.00  abnormal       True    NaN
# 49                     0.00  abnormal      False    NaN
# 50                     0.00  abnormal      False    NaN
# 51                     0.00  abnormal      False    NaN
# 52                    98.10    normal      False    NaN
# 53                    91.00    normal      False    NaN
# 54                    50.60  abnormal       True    NaN
# 55                    98.10    normal      False    NaN
# 56                    94.00    normal      False    NaN
# 57                    50.60  abnormal      False    NaN
# 58                   100.00    normal      False    NaN
# 59                    95.10    normal      False    NaN
# 60                    55.00  abnormal       True    NaN
# 61                    96.60    normal      False    NaN
# 62                    98.90    normal      False    NaN
# 63                    49.10  abnormal      False    NaN
# 70                     0.00  abnormal      False    NaN
# 71                     0.00  abnormal      False    NaN
# 72                     0.00  abnormal       True    NaN
# 73                     0.00  abnormal      False    NaN
# 74                     0.00  abnormal      False    NaN
# 75                     0.00  abnormal      False    NaN

# %%
exp_results.shape
# Out:
# (58, 11)

# %%
exp_mean = exp_results['accuracy-score'].mean()
exp_min = exp_results['accuracy-score'].min()
exp_max = exp_results['accuracy-score'].max()

expb_mean = exp_results['balanced-accuracy-score'].mean()
expb_min = exp_results['balanced-accuracy-score'].min()
expb_max = exp_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {exp_mean}, Min: {exp_min}, Max: {exp_max}')
print(f'Experiment Stats -- Mean: {expb_mean}, Min: {expb_min}, Max: {expb_max}')
print(f'Dimensions: {exp_results.shape}')
# Out:
# Experiment Stats -- Mean: 77.24637931034482, Min: 0.0, Max: 100.0
# Experiment Stats -- Mean: 54.47120689655172, Min: 0.0, Max: 100.0
# Dimensions: (58, 11)

# %%
opt_results = exp_results[exp_results['optimized']==True]
opt_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 2                 2                       DT                 NaN
# 3                 3                       DT                 NaN
# 6                 6                      SVM        hypertangent
# 12               12                      SVM        hypertangent
# 24               24                      SVM        hypertangent
# 30               30                      SVM          polynomial
# 36               36                      SVM          polynomial
# 48               48                      SVM          polynomial
# 54               54                      SVM                 rbf
# 60               60                      SVM                 rbf
# 72               72                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           93.03
# 1      random-relative                  NaN               NaN           94.20
# 2       first-absolute                  NaN               NaN           21.31
# 3       first-relative                  NaN               NaN           97.10
# 6      random-absolute                 drop           z-score           94.94
# 12     random-relative                 drop           z-score           97.10
# 24      first-relative                 drop           z-score           63.64
# 30     random-absolute                 drop           z-score           97.91
# 36     random-relative                 drop           z-score           98.53
# 48      first-relative                 drop           z-score          100.00
# 54     random-absolute                 drop           z-score           42.13
# 60     random-relative                 drop           z-score           46.38
# 72      first-relative                 drop           z-score            3.03
#
#     balanced-accuracy-score  f1-score  optimized reason
# 0                     93.03    normal       True    NaN
# 1                     93.60    normal       True    NaN
# 2                      0.50  abnormal       True    NaN
# 3                      0.00  abnormal       True    NaN
# 6                     94.40    normal       True    NaN
# 12                    97.70    normal       True    NaN
# 24                     0.00  abnormal       True    NaN
# 30                    97.60    normal       True    NaN
# 36                    99.20    normal       True    NaN
# 48                     0.00  abnormal       True    NaN
# 54                    50.60  abnormal       True    NaN
# 60                    55.00  abnormal       True    NaN
# 72                     0.00  abnormal       True    NaN

# %%
opt_mean = opt_results['accuracy-score'].mean()
opt_min = opt_results['accuracy-score'].min()
opt_max = opt_results['accuracy-score'].max()

optb_mean = opt_results['balanced-accuracy-score'].mean()
optb_min = opt_results['balanced-accuracy-score'].min()
optb_max = opt_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {opt_mean}, Min: {opt_min}, Max: {opt_max}')
print(f'Experiment Stats -- Mean: {optb_mean}, Min: {optb_min}, Max: {optb_max}')
print(f'Dimensions: {opt_results.shape}')
# Out:
# Experiment Stats -- Mean: 73.02307692307691, Min: 3.03, Max: 100.0
# Experiment Stats -- Mean: 52.43307692307693, Min: 0.0, Max: 99.2
# Dimensions: (13, 11)

# %%
dt_results = exp_results[exp_results['classification-algorithm']=="DT"]
dt_results
# Out:
#    workflow-number classification-algorithm algorithm-component  \
# 0                0                       DT                 NaN
# 1                1                       DT                 NaN
# 2                2                       DT                 NaN
# 3                3                       DT                 NaN
#
#   partition-component Imputation-component scaling-component  accuracy-score  \
# 0     random-absolute                  NaN               NaN           93.03
# 1     random-relative                  NaN               NaN           94.20
# 2      first-absolute                  NaN               NaN           21.31
# 3      first-relative                  NaN               NaN           97.10
#
#    balanced-accuracy-score  f1-score  optimized reason
# 0                    93.03    normal       True    NaN
# 1                    93.60    normal       True    NaN
# 2                     0.50  abnormal       True    NaN
# 3                     0.00  abnormal       True    NaN

# %%
dt_mean = dt_results['accuracy-score'].mean()
dt_min = dt_results['accuracy-score'].min()
dt_max = dt_results['accuracy-score'].max()

dtb_mean = dt_results['balanced-accuracy-score'].mean()
dtb_min = dt_results['balanced-accuracy-score'].min()
dtb_max = dt_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {dt_mean}, Min: {dt_min}, Max: {dt_max}')
print(f'Experiment Stats -- Mean: {dtb_mean}, Min: {dtb_min}, Max: {dtb_max}')
print(f'Dimensions: {dt_results.shape}')
# Out:
# Experiment Stats -- Mean: 76.41, Min: 21.31, Max: 97.1
# Experiment Stats -- Mean: 46.7825, Min: 0.0, Max: 93.6
# Dimensions: (4, 11)

# %%
svm_results = exp_results[exp_results['classification-algorithm']=="SVM"]
svm_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 4                 4                      SVM        hypertangent
# 5                 5                      SVM        hypertangent
# 6                 6                      SVM        hypertangent
# 7                 7                      SVM        hypertangent
# 8                 8                      SVM        hypertangent
# 9                 9                      SVM        hypertangent
# 10               10                      SVM        hypertangent
# 11               11                      SVM        hypertangent
# 12               12                      SVM        hypertangent
# 13               13                      SVM        hypertangent
# 14               14                      SVM        hypertangent
# 15               15                      SVM        hypertangent
# 22               22                      SVM        hypertangent
# 23               23                      SVM        hypertangent
# 24               24                      SVM        hypertangent
# 25               25                      SVM        hypertangent
# 26               26                      SVM        hypertangent
# 27               27                      SVM        hypertangent
# 28               28                      SVM          polynomial
# 29               29                      SVM          polynomial
# 30               30                      SVM          polynomial
# 31               31                      SVM          polynomial
# 32               32                      SVM          polynomial
# 33               33                      SVM          polynomial
# 34               34                      SVM          polynomial
# 35               35                      SVM          polynomial
# 36               36                      SVM          polynomial
# 37               37                      SVM          polynomial
# 38               38                      SVM          polynomial
# 39               39                      SVM          polynomial
# 46               46                      SVM          polynomial
# 47               47                      SVM          polynomial
# 48               48                      SVM          polynomial
# 49               49                      SVM          polynomial
# 50               50                      SVM          polynomial
# 51               51                      SVM          polynomial
# 52               52                      SVM                 rbf
# 53               53                      SVM                 rbf
# 54               54                      SVM                 rbf
# 55               55                      SVM                 rbf
# 56               56                      SVM                 rbf
# 57               57                      SVM                 rbf
# 58               58                      SVM                 rbf
# 59               59                      SVM                 rbf
# 60               60                      SVM                 rbf
# 61               61                      SVM                 rbf
# 62               62                      SVM                 rbf
# 63               63                      SVM                 rbf
# 70               70                      SVM                 rbf
# 71               71                      SVM                 rbf
# 72               72                      SVM                 rbf
# 73               73                      SVM                 rbf
# 74               74                      SVM                 rbf
# 75               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 4      random-absolute                 drop           decimal           40.80
# 5      random-absolute                 drop           min-max            0.80
# 6      random-absolute                 drop           z-score           94.94
# 7      random-absolute                 mean           decimal           74.59
# 8      random-absolute                 mean           min-max           78.69
# 9      random-absolute                 mean           z-score           93.03
# 10     random-relative                 drop           decimal           76.81
# 11     random-relative                 drop           min-max           82.80
# 12     random-relative                 drop           z-score           97.10
# 13     random-relative                 mean           decimal           81.16
# 14     random-relative                 mean           min-max           78.26
# 15     random-relative                 mean           z-score           88.40
# 22      first-relative                 drop           decimal            0.00
# 23      first-relative                 drop           min-max          100.00
# 24      first-relative                 drop           z-score           63.64
# 25      first-relative                 mean           decimal            0.00
# 26      first-relative                 mean           min-max           98.55
# 27      first-relative                 mean           z-score           63.77
# 28     random-absolute                 drop           decimal           68.49
# 29     random-absolute                 drop           min-max           96.64
# 30     random-absolute                 drop           z-score           97.91
# 31     random-absolute                 mean           decimal           78.69
# 32     random-absolute                 mean           min-max           97.95
# 33     random-absolute                 mean           z-score           96.72
# 34     random-relative                 drop           decimal           81.82
# 35     random-relative                 drop           min-max           98.51
# 36     random-relative                 drop           z-score           98.53
# 37     random-relative                 mean           decimal           76.81
# 38     random-relative                 mean           min-max           97.10
# 39     random-relative                 mean           z-score          100.00
# 46      first-relative                 drop           decimal           66.67
# 47      first-relative                 drop           min-max          100.00
# 48      first-relative                 drop           z-score          100.00
# 49      first-relative                 mean           decimal           62.32
# 50      first-relative                 mean           min-max           98.55
# 51      first-relative                 mean           z-score           98.55
# 52     random-absolute                 drop           decimal           98.31
# 53     random-absolute                 drop           min-max           91.21
# 54     random-absolute                 drop           z-score           42.13
# 55     random-absolute                 mean           decimal           98.36
# 56     random-absolute                 mean           min-max           94.26
# 57     random-absolute                 mean           z-score           42.21
# 58     random-relative                 drop           decimal          100.00
# 59     random-relative                 drop           min-max           95.38
# 60     random-relative                 drop           z-score           46.38
# 61     random-relative                 mean           decimal           97.10
# 62     random-relative                 mean           min-max           98.55
# 63     random-relative                 mean           z-score           39.13
# 70      first-relative                 drop           decimal          100.00
# 71      first-relative                 drop           min-max          100.00
# 72      first-relative                 drop           z-score            3.03
# 73      first-relative                 mean           decimal           98.55
# 74      first-relative                 mean           min-max           98.55
# 75      first-relative                 mean           z-score            2.90
#
#     balanced-accuracy-score  f1-score  optimized reason
# 4                       0.5  abnormal      False    NaN
# 5                      77.3  abnormal      False    NaN
# 6                      94.4    normal       True    NaN
# 7                      75.2    normal      False    NaN
# 8                      76.9  abnormal      False    NaN
# 9                      92.5    normal      False    NaN
# 10                     75.2  abnormal      False    NaN
# 11                     77.9  abnormal      False    NaN
# 12                     97.7    normal       True    NaN
# 13                     76.1  abnormal      False    NaN
# 14                     76.9  abnormal      False    NaN
# 15                     89.2    normal      False    NaN
# 22                      0.0  abnormal      False    NaN
# 23                      0.0  abnormal      False    NaN
# 24                      0.0  abnormal       True    NaN
# 25                      0.0  abnormal      False    NaN
# 26                      0.0  abnormal      False    NaN
# 27                      0.0  abnormal      False    NaN
# 28                     70.7  abnormal      False    NaN
# 29                     96.2    normal      False    NaN
# 30                     97.6    normal       True    NaN
# 31                     77.2    normal      False    NaN
# 32                     97.9    normal      False    NaN
# 33                     97.2    normal      False    NaN
# 34                     78.0    normal      False    NaN
# 35                     98.0    normal      False    NaN
# 36                     99.2    normal       True    NaN
# 37                     76.3    normal      False    NaN
# 38                     97.0    normal      False    NaN
# 39                    100.0    normal      False    NaN
# 46                      0.0  abnormal      False    NaN
# 47                      0.0  abnormal      False    NaN
# 48                      0.0  abnormal       True    NaN
# 49                      0.0  abnormal      False    NaN
# 50                      0.0  abnormal      False    NaN
# 51                      0.0  abnormal      False    NaN
# 52                     98.1    normal      False    NaN
# 53                     91.0    normal      False    NaN
# 54                     50.6  abnormal       True    NaN
# 55                     98.1    normal      False    NaN
# 56                     94.0    normal      False    NaN
# 57                     50.6  abnormal      False    NaN
# 58                    100.0    normal      False    NaN
# 59                     95.1    normal      False    NaN
# 60                     55.0  abnormal       True    NaN
# 61                     96.6    normal      False    NaN
# 62                     98.9    normal      False    NaN
# 63                     49.1  abnormal      False    NaN
# 70                      0.0  abnormal      False    NaN
# 71                      0.0  abnormal      False    NaN
# 72                      0.0  abnormal       True    NaN
# 73                      0.0  abnormal      False    NaN
# 74                      0.0  abnormal      False    NaN
# 75                      0.0  abnormal      False    NaN

# %%
svm_mean = svm_results['accuracy-score'].mean()
svm_min = svm_results['accuracy-score'].min()
svm_max = svm_results['accuracy-score'].max()

svmb_mean = svm_results['balanced-accuracy-score'].mean()
svmb_min = svm_results['balanced-accuracy-score'].min()
svmb_max = svm_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {svm_mean}, Min: {svm_min}, Max: {svm_max}')
print(f'Experiment Stats -- Mean: {svmb_mean}, Min: {svmb_min}, Max: {svmb_max}')
print(f'Dimensions: {svm_results.shape}')
# Out:
# Experiment Stats -- Mean: 77.30833333333332, Min: 0.0, Max: 100.0
# Experiment Stats -- Mean: 55.040740740740745, Min: 0.0, Max: 100.0
# Dimensions: (54, 11)

# %%
opt_svm_results = svm_results[svm_results['optimized']==True]
opt_svm_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 6                 6                      SVM        hypertangent
# 12               12                      SVM        hypertangent
# 24               24                      SVM        hypertangent
# 30               30                      SVM          polynomial
# 36               36                      SVM          polynomial
# 48               48                      SVM          polynomial
# 54               54                      SVM                 rbf
# 60               60                      SVM                 rbf
# 72               72                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 6      random-absolute                 drop           z-score           94.94
# 12     random-relative                 drop           z-score           97.10
# 24      first-relative                 drop           z-score           63.64
# 30     random-absolute                 drop           z-score           97.91
# 36     random-relative                 drop           z-score           98.53
# 48      first-relative                 drop           z-score          100.00
# 54     random-absolute                 drop           z-score           42.13
# 60     random-relative                 drop           z-score           46.38
# 72      first-relative                 drop           z-score            3.03
#
#     balanced-accuracy-score  f1-score  optimized reason
# 6                      94.4    normal       True    NaN
# 12                     97.7    normal       True    NaN
# 24                      0.0  abnormal       True    NaN
# 30                     97.6    normal       True    NaN
# 36                     99.2    normal       True    NaN
# 48                      0.0  abnormal       True    NaN
# 54                     50.6  abnormal       True    NaN
# 60                     55.0  abnormal       True    NaN
# 72                      0.0  abnormal       True    NaN

# %%
opt_svm_mean = opt_svm_results['accuracy-score'].mean()
opt_svm_min = opt_svm_results['accuracy-score'].min()
opt_svm_max = opt_svm_results['accuracy-score'].max()

optb_svm_mean = opt_svm_results['balanced-accuracy-score'].mean()
optb_svm_min = opt_svm_results['balanced-accuracy-score'].min()
optb_svm_max = opt_svm_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {opt_svm_mean}, Min: {opt_svm_min}, Max: {opt_svm_max}')
print(f'Experiment Stats -- Mean: {optb_svm_mean}, Min: {optb_svm_min}, Max: {optb_svm_max}')
print(f'Dimensions: {opt_svm_results.shape}')
# Out:
# Experiment Stats -- Mean: 71.51777777777778, Min: 3.03, Max: 100.0
# Experiment Stats -- Mean: 54.94444444444445, Min: 0.0, Max: 99.2
# Dimensions: (9, 11)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Balanced Accuracy': (
        list(exp_results['balanced-accuracy-score']) +
        list(opt_results['balanced-accuracy-score']) +
        list(dt_results['balanced-accuracy-score']) +
        list(svm_results['balanced-accuracy-score']) +
        list(opt_svm_results['balanced-accuracy-score'])
    ),
    'Workflow Category': (
        ['All Workflows'] * len(exp_results['balanced-accuracy-score']) +
        ['Selected Workflows'] * len(opt_results['balanced-accuracy-score']) +
        ['DT Workflows'] * len(dt_results['balanced-accuracy-score']) +
        ['SVM Workflows'] * len(svm_results['balanced-accuracy-score']) +
        ['Selected SVM Workflows'] * len(opt_svm_results['balanced-accuracy-score'])
    )
}

df = pd.DataFrame(data)

sns.set_style("whitegrid")

plt.figure(figsize=(12, 7))
sns.boxplot(x='Workflow Category', y='Balanced Accuracy', data=df, palette="Set2")

plt.title('Balanced Accuracy Across Workflow Categories', fontsize=16, fontweight='bold')
plt.xlabel('Workflow Categories', fontsize=14)
plt.ylabel('Balanced Accuracy', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()
# Out:
# /tmp/ipykernel_981816/3082467574.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Workflow Category', y='Balanced Accuracy', data=df, palette="Set2")

# %% [markdown]
# # Overall View (with Eliminating Invalid Classifiers)

# %%
clean_exp_results = exp_results[exp_results['f1-score']=="normal"]

clean_exp_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 6                 6                      SVM        hypertangent
# 7                 7                      SVM        hypertangent
# 9                 9                      SVM        hypertangent
# 12               12                      SVM        hypertangent
# 15               15                      SVM        hypertangent
# 29               29                      SVM          polynomial
# 30               30                      SVM          polynomial
# 31               31                      SVM          polynomial
# 32               32                      SVM          polynomial
# 33               33                      SVM          polynomial
# 34               34                      SVM          polynomial
# 35               35                      SVM          polynomial
# 36               36                      SVM          polynomial
# 37               37                      SVM          polynomial
# 38               38                      SVM          polynomial
# 39               39                      SVM          polynomial
# 52               52                      SVM                 rbf
# 53               53                      SVM                 rbf
# 55               55                      SVM                 rbf
# 56               56                      SVM                 rbf
# 58               58                      SVM                 rbf
# 59               59                      SVM                 rbf
# 61               61                      SVM                 rbf
# 62               62                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           93.03
# 1      random-relative                  NaN               NaN           94.20
# 6      random-absolute                 drop           z-score           94.94
# 7      random-absolute                 mean           decimal           74.59
# 9      random-absolute                 mean           z-score           93.03
# 12     random-relative                 drop           z-score           97.10
# 15     random-relative                 mean           z-score           88.40
# 29     random-absolute                 drop           min-max           96.64
# 30     random-absolute                 drop           z-score           97.91
# 31     random-absolute                 mean           decimal           78.69
# 32     random-absolute                 mean           min-max           97.95
# 33     random-absolute                 mean           z-score           96.72
# 34     random-relative                 drop           decimal           81.82
# 35     random-relative                 drop           min-max           98.51
# 36     random-relative                 drop           z-score           98.53
# 37     random-relative                 mean           decimal           76.81
# 38     random-relative                 mean           min-max           97.10
# 39     random-relative                 mean           z-score          100.00
# 52     random-absolute                 drop           decimal           98.31
# 53     random-absolute                 drop           min-max           91.21
# 55     random-absolute                 mean           decimal           98.36
# 56     random-absolute                 mean           min-max           94.26
# 58     random-relative                 drop           decimal          100.00
# 59     random-relative                 drop           min-max           95.38
# 61     random-relative                 mean           decimal           97.10
# 62     random-relative                 mean           min-max           98.55
#
#     balanced-accuracy-score f1-score  optimized reason
# 0                     93.03   normal       True    NaN
# 1                     93.60   normal       True    NaN
# 6                     94.40   normal       True    NaN
# 7                     75.20   normal      False    NaN
# 9                     92.50   normal      False    NaN
# 12                    97.70   normal       True    NaN
# 15                    89.20   normal      False    NaN
# 29                    96.20   normal      False    NaN
# 30                    97.60   normal       True    NaN
# 31                    77.20   normal      False    NaN
# 32                    97.90   normal      False    NaN
# 33                    97.20   normal      False    NaN
# 34                    78.00   normal      False    NaN
# 35                    98.00   normal      False    NaN
# 36                    99.20   normal       True    NaN
# 37                    76.30   normal      False    NaN
# 38                    97.00   normal      False    NaN
# 39                   100.00   normal      False    NaN
# 52                    98.10   normal      False    NaN
# 53                    91.00   normal      False    NaN
# 55                    98.10   normal      False    NaN
# 56                    94.00   normal      False    NaN
# 58                   100.00   normal      False    NaN
# 59                    95.10   normal      False    NaN
# 61                    96.60   normal      False    NaN
# 62                    98.90   normal      False    NaN

# %%
clean_exp_results.shape
# Out:
# (26, 11)

# %%
clean_exp_mean = clean_exp_results['accuracy-score'].mean()
clean_exp_min = clean_exp_results['accuracy-score'].min()
clean_exp_max = clean_exp_results['accuracy-score'].max()

clean_expb_mean = clean_exp_results['balanced-accuracy-score'].mean()
clean_expb_min = clean_exp_results['balanced-accuracy-score'].min()
clean_expb_max = clean_exp_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {clean_exp_mean}, Min: {clean_exp_min}, Max: {clean_exp_max}')
print(f'Experiment Stats -- Mean: {clean_expb_mean}, Min: {clean_expb_min}, Max: {clean_expb_max}')
print(f'Dimensions: {clean_exp_results.shape}')
# Out:
# Experiment Stats -- Mean: 93.42846153846153, Min: 74.59, Max: 100.0
# Experiment Stats -- Mean: 93.15499999999999, Min: 75.2, Max: 100.0
# Dimensions: (26, 11)

# %%
clean_opt_results = clean_exp_results[clean_exp_results['optimized']==True]
clean_opt_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 6                 6                      SVM        hypertangent
# 12               12                      SVM        hypertangent
# 30               30                      SVM          polynomial
# 36               36                      SVM          polynomial
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           93.03
# 1      random-relative                  NaN               NaN           94.20
# 6      random-absolute                 drop           z-score           94.94
# 12     random-relative                 drop           z-score           97.10
# 30     random-absolute                 drop           z-score           97.91
# 36     random-relative                 drop           z-score           98.53
#
#     balanced-accuracy-score f1-score  optimized reason
# 0                     93.03   normal       True    NaN
# 1                     93.60   normal       True    NaN
# 6                     94.40   normal       True    NaN
# 12                    97.70   normal       True    NaN
# 30                    97.60   normal       True    NaN
# 36                    99.20   normal       True    NaN

# %%
clean_opt_mean = clean_opt_results['accuracy-score'].mean()
clean_opt_min = clean_opt_results['accuracy-score'].min()
clean_opt_max = clean_opt_results['accuracy-score'].max()

clean_optb_mean = clean_opt_results['balanced-accuracy-score'].mean()
clean_optb_min = clean_opt_results['balanced-accuracy-score'].min()
clean_optb_max = clean_opt_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {clean_opt_mean}, Min: {clean_opt_min}, Max: {clean_opt_max}')
print(f'Experiment Stats -- Mean: {clean_optb_mean}, Min: {clean_optb_min}, Max: {clean_optb_max}')
print(f'Dimensions: {clean_opt_results.shape}')
# Out:
# Experiment Stats -- Mean: 95.95166666666665, Min: 93.03, Max: 98.53
# Experiment Stats -- Mean: 95.92166666666667, Min: 93.03, Max: 99.2
# Dimensions: (6, 11)

# %%
clean_svm_results = clean_exp_results[clean_exp_results['classification-algorithm']=="SVM"]
clean_svm_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 6                 6                      SVM        hypertangent
# 7                 7                      SVM        hypertangent
# 9                 9                      SVM        hypertangent
# 12               12                      SVM        hypertangent
# 15               15                      SVM        hypertangent
# 29               29                      SVM          polynomial
# 30               30                      SVM          polynomial
# 31               31                      SVM          polynomial
# 32               32                      SVM          polynomial
# 33               33                      SVM          polynomial
# 34               34                      SVM          polynomial
# 35               35                      SVM          polynomial
# 36               36                      SVM          polynomial
# 37               37                      SVM          polynomial
# 38               38                      SVM          polynomial
# 39               39                      SVM          polynomial
# 52               52                      SVM                 rbf
# 53               53                      SVM                 rbf
# 55               55                      SVM                 rbf
# 56               56                      SVM                 rbf
# 58               58                      SVM                 rbf
# 59               59                      SVM                 rbf
# 61               61                      SVM                 rbf
# 62               62                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 6      random-absolute                 drop           z-score           94.94
# 7      random-absolute                 mean           decimal           74.59
# 9      random-absolute                 mean           z-score           93.03
# 12     random-relative                 drop           z-score           97.10
# 15     random-relative                 mean           z-score           88.40
# 29     random-absolute                 drop           min-max           96.64
# 30     random-absolute                 drop           z-score           97.91
# 31     random-absolute                 mean           decimal           78.69
# 32     random-absolute                 mean           min-max           97.95
# 33     random-absolute                 mean           z-score           96.72
# 34     random-relative                 drop           decimal           81.82
# 35     random-relative                 drop           min-max           98.51
# 36     random-relative                 drop           z-score           98.53
# 37     random-relative                 mean           decimal           76.81
# 38     random-relative                 mean           min-max           97.10
# 39     random-relative                 mean           z-score          100.00
# 52     random-absolute                 drop           decimal           98.31
# 53     random-absolute                 drop           min-max           91.21
# 55     random-absolute                 mean           decimal           98.36
# 56     random-absolute                 mean           min-max           94.26
# 58     random-relative                 drop           decimal          100.00
# 59     random-relative                 drop           min-max           95.38
# 61     random-relative                 mean           decimal           97.10
# 62     random-relative                 mean           min-max           98.55
#
#     balanced-accuracy-score f1-score  optimized reason
# 6                      94.4   normal       True    NaN
# 7                      75.2   normal      False    NaN
# 9                      92.5   normal      False    NaN
# 12                     97.7   normal       True    NaN
# 15                     89.2   normal      False    NaN
# 29                     96.2   normal      False    NaN
# 30                     97.6   normal       True    NaN
# 31                     77.2   normal      False    NaN
# 32                     97.9   normal      False    NaN
# 33                     97.2   normal      False    NaN
# 34                     78.0   normal      False    NaN
# 35                     98.0   normal      False    NaN
# 36                     99.2   normal       True    NaN
# 37                     76.3   normal      False    NaN
# 38                     97.0   normal      False    NaN
# 39                    100.0   normal      False    NaN
# 52                     98.1   normal      False    NaN
# 53                     91.0   normal      False    NaN
# 55                     98.1   normal      False    NaN
# 56                     94.0   normal      False    NaN
# 58                    100.0   normal      False    NaN
# 59                     95.1   normal      False    NaN
# 61                     96.6   normal      False    NaN
# 62                     98.9   normal      False    NaN

# %%
grouped_df = clean_svm_results.groupby(['Imputation-component']).count()
grouped_df
# Out:
#                       workflow-number  classification-algorithm  \
# Imputation-component
# drop                               11                        11
# mean                               13                        13
#
#                       algorithm-component  partition-component  \
# Imputation-component
# drop                                   11                   11
# mean                                   13                   13
#
#                       scaling-component  accuracy-score  \
# Imputation-component
# drop                                 11              11
# mean                                 13              13
#
#                       balanced-accuracy-score  f1-score  optimized  reason
# Imputation-component
# drop                                       11        11         11       0
# mean                                       13        13         13       0

# %%
grouped_df_2 = clean_svm_results.groupby(['Imputation-component'])['balanced-accuracy-score'].mean()
grouped_df_2
# Out:
# Imputation-component
# drop    95.027273
# mean    91.546154
# Name: balanced-accuracy-score, dtype: float64

# %%
grouped_df_3 = clean_svm_results.groupby(['scaling-component']).count()
grouped_df_3
# Out:
#                    workflow-number  classification-algorithm  \
# scaling-component
# decimal                          8                         8
# min-max                          8                         8
# z-score                          8                         8
#
#                    algorithm-component  partition-component  \
# scaling-component
# decimal                              8                    8
# min-max                              8                    8
# z-score                              8                    8
#
#                    Imputation-component  accuracy-score  \
# scaling-component
# decimal                               8               8
# min-max                               8               8
# z-score                               8               8
#
#                    balanced-accuracy-score  f1-score  optimized  reason
# scaling-component
# decimal                                  8         8          8       0
# min-max                                  8         8          8       0
# z-score                                  8         8          8       0

# %%
grouped_df_4 = clean_svm_results.groupby(['scaling-component'])['balanced-accuracy-score'].mean()
grouped_df_4
# Out:
# scaling-component
# decimal    87.4375
# min-max    96.0125
# z-score    95.9750
# Name: balanced-accuracy-score, dtype: float64

# %%
grouped_df_4 = clean_svm_results.groupby(['optimized'])['balanced-accuracy-score'].mean()
grouped_df_4
# Out:
# optimized
# False    92.325
# True     97.225
# Name: balanced-accuracy-score, dtype: float64

# %%
clean_svm_mean = clean_svm_results['accuracy-score'].mean()
clean_svm_min = clean_svm_results['accuracy-score'].min()
clean_svm_max = clean_svm_results['accuracy-score'].max()

clean_svmb_mean = clean_svm_results['balanced-accuracy-score'].mean()
clean_svmb_min = clean_svm_results['balanced-accuracy-score'].min()
clean_svmb_max = clean_svm_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {clean_svm_mean}, Min: {clean_svm_min}, Max: {clean_svm_max}')
print(f'Experiment Stats -- Mean: {clean_svmb_mean}, Min: {clean_svmb_min}, Max: {clean_svmb_max}')
print(f'Dimensions: {clean_svm_results.shape}')
# Out:
# Experiment Stats -- Mean: 93.41291666666666, Min: 74.59, Max: 100.0
# Experiment Stats -- Mean: 93.14166666666665, Min: 75.2, Max: 100.0
# Dimensions: (24, 11)

# %%
clean_opt_svm_results = clean_svm_results[clean_svm_results['optimized']==True]
clean_opt_svm_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 6                 6                      SVM        hypertangent
# 12               12                      SVM        hypertangent
# 30               30                      SVM          polynomial
# 36               36                      SVM          polynomial
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 6      random-absolute                 drop           z-score           94.94
# 12     random-relative                 drop           z-score           97.10
# 30     random-absolute                 drop           z-score           97.91
# 36     random-relative                 drop           z-score           98.53
#
#     balanced-accuracy-score f1-score  optimized reason
# 6                      94.4   normal       True    NaN
# 12                     97.7   normal       True    NaN
# 30                     97.6   normal       True    NaN
# 36                     99.2   normal       True    NaN

# %%
clean_opt_svm_mean = clean_opt_svm_results['accuracy-score'].mean()
clean_opt_svm_min = clean_opt_svm_results['accuracy-score'].min()
clean_opt_svm_max = clean_opt_svm_results['accuracy-score'].max()

clean_optb_svm_mean = clean_opt_svm_results['balanced-accuracy-score'].mean()
clean_optb_svm_min = clean_opt_svm_results['balanced-accuracy-score'].min()
clean_optb_svm_max = clean_opt_svm_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {clean_opt_svm_mean}, Min: {clean_opt_svm_min}, Max: {clean_opt_svm_max}')
print(f'Experiment Stats -- Mean: {clean_optb_svm_mean}, Min: {clean_optb_svm_min}, Max: {clean_optb_svm_max}')
print(f'Dimensions: {clean_opt_svm_results.shape}')
# Out:
# Experiment Stats -- Mean: 97.12, Min: 94.94, Max: 98.53
# Experiment Stats -- Mean: 97.22500000000001, Min: 94.4, Max: 99.2
# Dimensions: (4, 11)

# %%
clean_dt_results = clean_exp_results[clean_exp_results['classification-algorithm']=="DT"]
clean_dt_results
# Out:
#    workflow-number classification-algorithm algorithm-component  \
# 0                0                       DT                 NaN
# 1                1                       DT                 NaN
#
#   partition-component Imputation-component scaling-component  accuracy-score  \
# 0     random-absolute                  NaN               NaN           93.03
# 1     random-relative                  NaN               NaN           94.20
#
#    balanced-accuracy-score f1-score  optimized reason
# 0                    93.03   normal       True    NaN
# 1                    93.60   normal       True    NaN

# %%
clean_dt_mean = clean_dt_results['accuracy-score'].mean()
clean_dt_min = clean_dt_results['accuracy-score'].min()
clean_dt_max = clean_dt_results['accuracy-score'].max()

clean_dtb_mean = clean_dt_results['balanced-accuracy-score'].mean()
clean_dtb_min = clean_dt_results['balanced-accuracy-score'].min()
clean_dtb_max = clean_dt_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {clean_dt_mean}, Min: {clean_dt_min}, Max: {clean_dt_max}')
print(f'Experiment Stats -- Mean: {clean_dtb_mean}, Min: {clean_dtb_min}, Max: {clean_dtb_max}')
print(f'Dimensions: {clean_dt_results.shape}')
# Out:
# Experiment Stats -- Mean: 93.61500000000001, Min: 93.03, Max: 94.2
# Experiment Stats -- Mean: 93.315, Min: 93.03, Max: 93.6
# Dimensions: (2, 11)

# %%
grouped_df_5 = clean_svm_results.groupby(['partition-component','Imputation-component','scaling-component'])['balanced-accuracy-score'].mean()
grouped_df_5
# Out:
# partition-component  Imputation-component  scaling-component
# random-absolute      drop                  decimal              98.10
#                                            min-max              93.60
#                                            z-score              96.00
#                      mean                  decimal              83.50
#                                            min-max              95.95
#                                            z-score              94.85
# random-relative      drop                  decimal              89.00
#                                            min-max              96.55
#                                            z-score              98.45
#                      mean                  decimal              86.45
#                                            min-max              97.95
#                                            z-score              94.60
# Name: balanced-accuracy-score, dtype: float64

# %%
grouped_df_6 = clean_opt_svm_results.groupby(['partition-component','Imputation-component','scaling-component'])['balanced-accuracy-score'].mean()
grouped_df_6
# Out:
# partition-component  Imputation-component  scaling-component
# random-absolute      drop                  z-score              96.00
# random-relative      drop                  z-score              98.45
# Name: balanced-accuracy-score, dtype: float64

# %%
data = {
    'Balanced Accuracy': (
        list(clean_exp_results['balanced-accuracy-score']) +
        list(clean_opt_results['balanced-accuracy-score']) +
        list(clean_dt_results['balanced-accuracy-score']) +
        list(clean_svm_results['balanced-accuracy-score']) +
        list(clean_opt_svm_results['balanced-accuracy-score'])
    ),
    'Workflow Category': (
        ['All Workflows'] * len(clean_exp_results['balanced-accuracy-score']) +
        ['Selected Workflows'] * len(clean_opt_results['balanced-accuracy-score']) +
        ['DT Workflows'] * len(clean_dt_results['balanced-accuracy-score']) +
        ['SVM Workflows'] * len(clean_svm_results['balanced-accuracy-score']) +
        ['Selected SVM Workflows'] * len(clean_opt_svm_results['balanced-accuracy-score'])
    )
}

df = pd.DataFrame(data)

sns.set_style("whitegrid")

plt.figure(figsize=(12, 7))
sns.boxplot(x='Workflow Category', y='Balanced Accuracy', data=df, palette="Set2")

plt.title('Valid Workflow Categories', fontsize=16, fontweight='bold')
plt.xlabel('Workflow Categories', fontsize=14)
plt.ylabel('Balanced Accuracy', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
# Out:
# /tmp/ipykernel_981816/4021895740.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Workflow Category', y='Balanced Accuracy', data=df, palette="Set2")
# (array([ 70.,  75.,  80.,  85.,  90.,  95., 100., 105.]),
#  [Text(0, 70.0, '70'),
#   Text(0, 75.0, '75'),
#   Text(0, 80.0, '80'),
#   Text(0, 85.0, '85'),
#   Text(0, 90.0, '90'),
#   Text(0, 95.0, '95'),
#   Text(0, 100.0, '100'),
#   Text(0, 105.0, '105')])
