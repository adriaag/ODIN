# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Overall View

# %%
exp_results = pd.read_csv('result-comparison.csv')

exp_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 2                 2                       DT                 NaN
# 3                 3                       DT                 NaN
# 4                 9                      SVM        hypertangent
# ..              ...                      ...                 ...
# 71               70                      SVM                 rbf
# 72               71                      SVM                 rbf
# 73               72                      SVM                 rbf
# 74               73                      SVM                 rbf
# 75               74                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           78.26
# 1      random-relative                  NaN               NaN           82.12
# 2       first-absolute                  NaN               NaN           77.20
# 3       first-relative                  NaN               NaN           82.68
# 4      random-absolute                 mean           z-score           63.84
# ..                 ...                  ...               ...             ...
# 71      first-relative                 drop           decimal           72.22
# 72      first-relative                 drop           min-max           72.22
# 73      first-relative                 drop           z-score           72.22
# 74      first-relative                 mean           decimal           69.27
# 75      first-relative                 mean           min-max           68.16
#
#     balanced-accuracy-score  f1-score-survived  optimized
# 0                     72.40               62.3       True
# 1                     80.20               73.3       True
# 2                     73.90               66.7       True
# 3                     82.68               77.4       True
# 4                     57.60               39.1       True
# ..                      ...                ...        ...
# 71                    50.00               83.9      False
# 72                    50.00               83.9      False
# 73                    50.00               83.9      False
# 74                    60.50               40.9      False
# 75                    58.90               37.4      False
#
# [76 rows x 10 columns]

# %%
exp_mean = exp_results['accuracy-score'].mean()
exp_min = exp_results['accuracy-score'].min()
exp_max = exp_results['accuracy-score'].max()

expb_mean = exp_results['balanced-accuracy-score'].mean()
expb_min = exp_results['balanced-accuracy-score'].min()
expb_max = exp_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {exp_mean}, Min: {exp_min}, Max: {exp_max}')
print(f'Experiment Stats -- Mean: {expb_mean}, Min: {expb_min}, Max: {expb_max}')
# Out:
# Experiment Stats -- Mean: 64.97934210526316, Min: 28.92, Max: 82.68
# Experiment Stats -- Mean: 54.63131578947368, Min: 32.6, Max: 82.68

# %%
opt_results = exp_results[exp_results['optimized']==True]
opt_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 2                 2                       DT                 NaN
# 3                 3                       DT                 NaN
# 4                 9                      SVM        hypertangent
# 5                15                      SVM        hypertangent
# 6                21                      SVM        hypertangent
# 7                27                      SVM        hypertangent
# 8                33                      SVM          polynomial
# 9                39                      SVM          polynomial
# 10               45                      SVM          polynomial
# 11               51                      SVM          polynomial
# 12               57                      SVM                 rbf
# 13               63                      SVM                 rbf
# 14               69                      SVM                 rbf
# 15               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           78.26
# 1      random-relative                  NaN               NaN           82.12
# 2       first-absolute                  NaN               NaN           77.20
# 3       first-relative                  NaN               NaN           82.68
# 4      random-absolute                 mean           z-score           63.84
# 5      random-relative                 mean           z-score           54.19
# 6       first-absolute                 mean           z-score           60.94
# 7       first-relative                 mean           z-score           32.96
# 8      random-absolute                 mean           z-score           67.64
# 9      random-relative                 mean           z-score           71.51
# 10      first-absolute                 mean           z-score           61.82
# 11      first-relative                 mean           z-score           72.63
# 12     random-absolute                 mean           z-score           60.94
# 13     random-relative                 mean           z-score           56.42
# 14      first-absolute                 mean           z-score           61.95
# 15      first-relative                 mean           z-score           64.25
#
#     balanced-accuracy-score  f1-score-survived  optimized
# 0                     72.40              62.30       True
# 1                     80.20              73.30       True
# 2                     73.90              66.70       True
# 3                     82.68              77.40       True
# 4                     57.60              39.10       True
# 5                     49.40              33.90       True
# 6                     49.20               0.60       True
# 7                     32.60               0.25       True
# 8                     64.20              54.00       True
# 9                     68.00              57.10       True
# 10                    50.00               1.30       True
# 11                    68.60              58.80       True
# 12                    49.70               3.10       True
# 13                    48.50               4.90       True
# 14                    50.00                NaN       True
# 15                    50.30               3.00       True

# %%
opt_mean = opt_results['accuracy-score'].mean()
opt_min = opt_results['accuracy-score'].min()
opt_max = opt_results['accuracy-score'].max()

optb_mean = opt_results['balanced-accuracy-score'].mean()
optb_min = opt_results['balanced-accuracy-score'].min()
optb_max = opt_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {opt_mean}, Min: {opt_min}, Max: {opt_max}')
print(f'Experiment Stats -- Mean: {optb_mean}, Min: {optb_min}, Max: {optb_max}')
# Out:
# Experiment Stats -- Mean: 65.584375, Min: 32.96, Max: 82.68
# Experiment Stats -- Mean: 59.205000000000005, Min: 32.6, Max: 82.68

# %%
dt_results = exp_results[exp_results['classification-algorithm']=="DT"]
dt_results
# Out:
#    workflow-number classification-algorithm algorithm-component  \
# 0                0                       DT                 NaN
# 1                1                       DT                 NaN
# 2                2                       DT                 NaN
# 3                3                       DT                 NaN
#
#   partition-component Imputation-component scaling-component  accuracy-score  \
# 0     random-absolute                  NaN               NaN           78.26
# 1     random-relative                  NaN               NaN           82.12
# 2      first-absolute                  NaN               NaN           77.20
# 3      first-relative                  NaN               NaN           82.68
#
#    balanced-accuracy-score  f1-score-survived  optimized
# 0                    72.40               62.3       True
# 1                    80.20               73.3       True
# 2                    73.90               66.7       True
# 3                    82.68               77.4       True

# %%
dt_mean = dt_results['accuracy-score'].mean()
dt_min = dt_results['accuracy-score'].min()
dt_max = dt_results['accuracy-score'].max()

dtb_mean = dt_results['balanced-accuracy-score'].mean()
dtb_min = dt_results['balanced-accuracy-score'].min()
dtb_max = dt_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {dt_mean}, Min: {dt_min}, Max: {dt_max}')
print(f'Experiment Stats -- Mean: {dtb_mean}, Min: {dtb_min}, Max: {dtb_max}')
# Out:
# Experiment Stats -- Mean: 80.065, Min: 77.2, Max: 82.68
# Experiment Stats -- Mean: 77.29500000000002, Min: 72.4, Max: 82.68

# %%
svm_results = exp_results[exp_results['classification-algorithm']=="SVM"]
svm_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 4                 9                      SVM        hypertangent
# 5                15                      SVM        hypertangent
# 6                21                      SVM        hypertangent
# 7                27                      SVM        hypertangent
# 8                33                      SVM          polynomial
# ..              ...                      ...                 ...
# 71               70                      SVM                 rbf
# 72               71                      SVM                 rbf
# 73               72                      SVM                 rbf
# 74               73                      SVM                 rbf
# 75               74                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 4      random-absolute                 mean           z-score           63.84
# 5      random-relative                 mean           z-score           54.19
# 6       first-absolute                 mean           z-score           60.94
# 7       first-relative                 mean           z-score           32.96
# 8      random-absolute                 mean           z-score           67.64
# ..                 ...                  ...               ...             ...
# 71      first-relative                 drop           decimal           72.22
# 72      first-relative                 drop           min-max           72.22
# 73      first-relative                 drop           z-score           72.22
# 74      first-relative                 mean           decimal           69.27
# 75      first-relative                 mean           min-max           68.16
#
#     balanced-accuracy-score  f1-score-survived  optimized
# 4                      57.6              39.10       True
# 5                      49.4              33.90       True
# 6                      49.2               0.60       True
# 7                      32.6               0.25       True
# 8                      64.2              54.00       True
# ..                      ...                ...        ...
# 71                     50.0              83.90      False
# 72                     50.0              83.90      False
# 73                     50.0              83.90      False
# 74                     60.5              40.90      False
# 75                     58.9              37.40      False
#
# [72 rows x 10 columns]

# %%
svm_mean = svm_results['accuracy-score'].mean()
svm_min = svm_results['accuracy-score'].min()
svm_max = svm_results['accuracy-score'].max()

svmb_mean = svm_results['balanced-accuracy-score'].mean()
svmb_min = svm_results['balanced-accuracy-score'].min()
svmb_max = svm_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {svm_mean}, Min: {svm_min}, Max: {svm_max}')
print(f'Experiment Stats -- Mean: {svmb_mean}, Min: {svmb_min}, Max: {svmb_max}')
# Out:
# Experiment Stats -- Mean: 64.14125, Min: 28.92, Max: 75.42
# Experiment Stats -- Mean: 53.37222222222222, Min: 32.6, Max: 70.4

# %%
opt_svm_results = svm_results[svm_results['optimized']==True]
opt_svm_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 4                 9                      SVM        hypertangent
# 5                15                      SVM        hypertangent
# 6                21                      SVM        hypertangent
# 7                27                      SVM        hypertangent
# 8                33                      SVM          polynomial
# 9                39                      SVM          polynomial
# 10               45                      SVM          polynomial
# 11               51                      SVM          polynomial
# 12               57                      SVM                 rbf
# 13               63                      SVM                 rbf
# 14               69                      SVM                 rbf
# 15               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 4      random-absolute                 mean           z-score           63.84
# 5      random-relative                 mean           z-score           54.19
# 6       first-absolute                 mean           z-score           60.94
# 7       first-relative                 mean           z-score           32.96
# 8      random-absolute                 mean           z-score           67.64
# 9      random-relative                 mean           z-score           71.51
# 10      first-absolute                 mean           z-score           61.82
# 11      first-relative                 mean           z-score           72.63
# 12     random-absolute                 mean           z-score           60.94
# 13     random-relative                 mean           z-score           56.42
# 14      first-absolute                 mean           z-score           61.95
# 15      first-relative                 mean           z-score           64.25
#
#     balanced-accuracy-score  f1-score-survived  optimized
# 4                      57.6              39.10       True
# 5                      49.4              33.90       True
# 6                      49.2               0.60       True
# 7                      32.6               0.25       True
# 8                      64.2              54.00       True
# 9                      68.0              57.10       True
# 10                     50.0               1.30       True
# 11                     68.6              58.80       True
# 12                     49.7               3.10       True
# 13                     48.5               4.90       True
# 14                     50.0                NaN       True
# 15                     50.3               3.00       True

# %%
opt_svm_mean = opt_svm_results['accuracy-score'].mean()
opt_svm_min = opt_svm_results['accuracy-score'].min()
opt_svm_max = opt_svm_results['accuracy-score'].max()

optb_svm_mean = opt_svm_results['balanced-accuracy-score'].mean()
optb_svm_min = opt_svm_results['balanced-accuracy-score'].min()
optb_svm_max = opt_svm_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {opt_svm_mean}, Min: {opt_svm_min}, Max: {opt_svm_max}')
print(f'Experiment Stats -- Mean: {optb_svm_mean}, Min: {optb_svm_min}, Max: {optb_svm_max}')
# Out:
# Experiment Stats -- Mean: 60.7575, Min: 32.96, Max: 72.63
# Experiment Stats -- Mean: 53.17499999999999, Min: 32.6, Max: 68.6

# %% [markdown]
# # Overall View (with Eliminating Worst Classifiers)

# %%
clean_exp_results = exp_results[exp_results['balanced-accuracy-score']>50]

clean_exp_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 2                 2                       DT                 NaN
# 3                 3                       DT                 NaN
# 4                 9                      SVM        hypertangent
# 8                33                      SVM          polynomial
# 9                39                      SVM          polynomial
# 11               51                      SVM          polynomial
# 15               75                      SVM                 rbf
# 25               14                      SVM        hypertangent
# 33               24                      SVM        hypertangent
# 35               26                      SVM        hypertangent
# 37               29                      SVM          polynomial
# 38               30                      SVM          polynomial
# 40               32                      SVM          polynomial
# 43               36                      SVM          polynomial
# 44               37                      SVM          polynomial
# 45               38                      SVM          polynomial
# 50               44                      SVM          polynomial
# 54               49                      SVM          polynomial
# 55               50                      SVM          polynomial
# 57               53                      SVM                 rbf
# 59               55                      SVM                 rbf
# 60               56                      SVM                 rbf
# 61               58                      SVM                 rbf
# 62               59                      SVM                 rbf
# 64               61                      SVM                 rbf
# 65               62                      SVM                 rbf
# 74               73                      SVM                 rbf
# 75               74                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           78.26
# 1      random-relative                  NaN               NaN           82.12
# 2       first-absolute                  NaN               NaN           77.20
# 3       first-relative                  NaN               NaN           82.68
# 4      random-absolute                 mean           z-score           63.84
# 8      random-absolute                 mean           z-score           67.64
# 9      random-relative                 mean           z-score           71.51
# 11      first-relative                 mean           z-score           72.63
# 15      first-relative                 mean           z-score           64.25
# 25     random-relative                 mean           min-max           67.04
# 33      first-relative                 drop           z-score           75.00
# 35      first-relative                 mean           min-max           73.74
# 37     random-absolute                 drop           min-max           66.25
# 38     random-absolute                 drop           z-score           49.40
# 40     random-absolute                 mean           min-max           71.05
# 43     random-relative                 drop           z-score           71.79
# 44     random-relative                 mean           decimal           67.04
# 45     random-relative                 mean           min-max           69.83
# 50      first-absolute                 mean           min-max           63.50
# 54      first-relative                 mean           decimal           75.42
# 55      first-relative                 mean           min-max           74.86
# 57     random-absolute                 drop           min-max           67.07
# 59     random-absolute                 mean           decimal           67.00
# 60     random-absolute                 mean           min-max           58.91
# 61     random-relative                 drop           decimal           72.73
# 62     random-relative                 drop           min-max           65.96
# 64     random-relative                 mean           decimal           75.40
# 65     random-relative                 mean           min-max           70.95
# 74      first-relative                 mean           decimal           69.27
# 75      first-relative                 mean           min-max           68.16
#
#     balanced-accuracy-score  f1-score-survived  optimized
# 0                     72.40               62.3       True
# 1                     80.20               73.3       True
# 2                     73.90               66.7       True
# 3                     82.68               77.4       True
# 4                     57.60               39.1       True
# 8                     64.20               54.0       True
# 9                     68.00               57.1       True
# 11                    68.60               58.8       True
# 15                    50.30                3.0       True
# 25                    61.00               44.9      False
# 33                    55.00               85.2      False
# 35                    67.40               55.2      False
# 37                    58.00               76.5      False
# 38                    51.30               55.3      False
# 40                    66.70               55.9      False
# 43                    63.40               80.7      False
# 44                    59.60               41.6      False
# 45                    66.00               55.7      False
# 50                    53.10               17.2      False
# 54                    69.40               58.5      False
# 55                    70.40               60.9      False
# 57                    52.20               79.4      False
# 59                    62.20               49.3      False
# 60                    51.90               29.5      False
# 61                    56.60               83.0      False
# 62                    53.70               77.8      False
# 64                    70.40               60.7      False
# 65                    67.10               56.7      False
# 74                    60.50               40.9      False
# 75                    58.90               37.4      False

# %%
clean_exp_mean = clean_exp_results['accuracy-score'].mean()
clean_exp_min = clean_exp_results['accuracy-score'].min()
clean_exp_max = clean_exp_results['accuracy-score'].max()

clean_expb_mean = clean_exp_results['balanced-accuracy-score'].mean()
clean_expb_min = clean_exp_results['balanced-accuracy-score'].min()
clean_expb_max = clean_exp_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {clean_exp_mean}, Min: {clean_exp_min}, Max: {clean_exp_max}')
print(f'Experiment Stats -- Mean: {clean_expb_mean}, Min: {clean_expb_min}, Max: {clean_expb_max}')
# Out:
# Experiment Stats -- Mean: 70.01666666666667, Min: 49.4, Max: 82.68
# Experiment Stats -- Mean: 63.089333333333336, Min: 50.3, Max: 82.68

# %%
clean_opt_results = clean_exp_results[clean_exp_results['optimized']==True]
clean_opt_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 0                 0                       DT                 NaN
# 1                 1                       DT                 NaN
# 2                 2                       DT                 NaN
# 3                 3                       DT                 NaN
# 4                 9                      SVM        hypertangent
# 8                33                      SVM          polynomial
# 9                39                      SVM          polynomial
# 11               51                      SVM          polynomial
# 15               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 0      random-absolute                  NaN               NaN           78.26
# 1      random-relative                  NaN               NaN           82.12
# 2       first-absolute                  NaN               NaN           77.20
# 3       first-relative                  NaN               NaN           82.68
# 4      random-absolute                 mean           z-score           63.84
# 8      random-absolute                 mean           z-score           67.64
# 9      random-relative                 mean           z-score           71.51
# 11      first-relative                 mean           z-score           72.63
# 15      first-relative                 mean           z-score           64.25
#
#     balanced-accuracy-score  f1-score-survived  optimized
# 0                     72.40               62.3       True
# 1                     80.20               73.3       True
# 2                     73.90               66.7       True
# 3                     82.68               77.4       True
# 4                     57.60               39.1       True
# 8                     64.20               54.0       True
# 9                     68.00               57.1       True
# 11                    68.60               58.8       True
# 15                    50.30                3.0       True

# %%
clean_opt_mean = clean_opt_results['accuracy-score'].mean()
clean_opt_min = clean_opt_results['accuracy-score'].min()
clean_opt_max = clean_opt_results['accuracy-score'].max()

clean_optb_mean = clean_opt_results['balanced-accuracy-score'].mean()
clean_optb_min = clean_opt_results['balanced-accuracy-score'].min()
clean_optb_max = clean_opt_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {clean_opt_mean}, Min: {clean_opt_min}, Max: {clean_opt_max}')
print(f'Experiment Stats -- Mean: {clean_optb_mean}, Min: {clean_optb_min}, Max: {clean_optb_max}')
# Out:
# Experiment Stats -- Mean: 73.34777777777778, Min: 63.84, Max: 82.68
# Experiment Stats -- Mean: 68.65333333333334, Min: 50.3, Max: 82.68

# %%
clean_svm_results = clean_exp_results[clean_exp_results['classification-algorithm']=="SVM"]
clean_svm_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 4                 9                      SVM        hypertangent
# 8                33                      SVM          polynomial
# 9                39                      SVM          polynomial
# 11               51                      SVM          polynomial
# 15               75                      SVM                 rbf
# 25               14                      SVM        hypertangent
# 33               24                      SVM        hypertangent
# 35               26                      SVM        hypertangent
# 37               29                      SVM          polynomial
# 38               30                      SVM          polynomial
# 40               32                      SVM          polynomial
# 43               36                      SVM          polynomial
# 44               37                      SVM          polynomial
# 45               38                      SVM          polynomial
# 50               44                      SVM          polynomial
# 54               49                      SVM          polynomial
# 55               50                      SVM          polynomial
# 57               53                      SVM                 rbf
# 59               55                      SVM                 rbf
# 60               56                      SVM                 rbf
# 61               58                      SVM                 rbf
# 62               59                      SVM                 rbf
# 64               61                      SVM                 rbf
# 65               62                      SVM                 rbf
# 74               73                      SVM                 rbf
# 75               74                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 4      random-absolute                 mean           z-score           63.84
# 8      random-absolute                 mean           z-score           67.64
# 9      random-relative                 mean           z-score           71.51
# 11      first-relative                 mean           z-score           72.63
# 15      first-relative                 mean           z-score           64.25
# 25     random-relative                 mean           min-max           67.04
# 33      first-relative                 drop           z-score           75.00
# 35      first-relative                 mean           min-max           73.74
# 37     random-absolute                 drop           min-max           66.25
# 38     random-absolute                 drop           z-score           49.40
# 40     random-absolute                 mean           min-max           71.05
# 43     random-relative                 drop           z-score           71.79
# 44     random-relative                 mean           decimal           67.04
# 45     random-relative                 mean           min-max           69.83
# 50      first-absolute                 mean           min-max           63.50
# 54      first-relative                 mean           decimal           75.42
# 55      first-relative                 mean           min-max           74.86
# 57     random-absolute                 drop           min-max           67.07
# 59     random-absolute                 mean           decimal           67.00
# 60     random-absolute                 mean           min-max           58.91
# 61     random-relative                 drop           decimal           72.73
# 62     random-relative                 drop           min-max           65.96
# 64     random-relative                 mean           decimal           75.40
# 65     random-relative                 mean           min-max           70.95
# 74      first-relative                 mean           decimal           69.27
# 75      first-relative                 mean           min-max           68.16
#
#     balanced-accuracy-score  f1-score-survived  optimized
# 4                      57.6               39.1       True
# 8                      64.2               54.0       True
# 9                      68.0               57.1       True
# 11                     68.6               58.8       True
# 15                     50.3                3.0       True
# 25                     61.0               44.9      False
# 33                     55.0               85.2      False
# 35                     67.4               55.2      False
# 37                     58.0               76.5      False
# 38                     51.3               55.3      False
# 40                     66.7               55.9      False
# 43                     63.4               80.7      False
# 44                     59.6               41.6      False
# 45                     66.0               55.7      False
# 50                     53.1               17.2      False
# 54                     69.4               58.5      False
# 55                     70.4               60.9      False
# 57                     52.2               79.4      False
# 59                     62.2               49.3      False
# 60                     51.9               29.5      False
# 61                     56.6               83.0      False
# 62                     53.7               77.8      False
# 64                     70.4               60.7      False
# 65                     67.1               56.7      False
# 74                     60.5               40.9      False
# 75                     58.9               37.4      False

# %%
grouped_df = clean_svm_results.groupby(['Imputation-component']).count()
grouped_df
# Out:
#                       workflow-number  classification-algorithm  \
# Imputation-component
# drop                                7                         7
# mean                               19                        19
#
#                       algorithm-component  partition-component  \
# Imputation-component
# drop                                    7                    7
# mean                                   19                   19
#
#                       scaling-component  accuracy-score  \
# Imputation-component
# drop                                  7               7
# mean                                 19              19
#
#                       balanced-accuracy-score  f1-score-survived  optimized
# Imputation-component
# drop                                        7                  7          7
# mean                                       19                 19         19

# %%
grouped_df_2 = clean_svm_results.groupby(['Imputation-component'])['balanced-accuracy-score'].mean()
grouped_df_2
# Out:
# Imputation-component
# drop    55.742857
# mean    62.805263
# Name: balanced-accuracy-score, dtype: float64

# %%
grouped_df_3 = clean_svm_results.groupby(['scaling-component']).count()
grouped_df_3
# Out:
#                    workflow-number  classification-algorithm  \
# scaling-component
# decimal                          6                         6
# min-max                         12                        12
# z-score                          8                         8
#
#                    algorithm-component  partition-component  \
# scaling-component
# decimal                              6                    6
# min-max                             12                   12
# z-score                              8                    8
#
#                    Imputation-component  accuracy-score  \
# scaling-component
# decimal                               6               6
# min-max                              12              12
# z-score                               8               8
#
#                    balanced-accuracy-score  f1-score-survived  optimized
# scaling-component
# decimal                                  6                  6          6
# min-max                                 12                 12         12
# z-score                                  8                  8          8

# %%
grouped_df_4 = clean_svm_results.groupby(['scaling-component'])['balanced-accuracy-score'].mean()
grouped_df_4
# Out:
# scaling-component
# decimal    63.116667
# min-max    60.533333
# z-score    59.800000
# Name: balanced-accuracy-score, dtype: float64

# %%
grouped_df_4 = clean_svm_results.groupby(['optimized'])['balanced-accuracy-score'].mean()
grouped_df_4
# Out:
# optimized
# False    60.704762
# True     61.740000
# Name: balanced-accuracy-score, dtype: float64

# %%
clean_svm_mean = clean_svm_results['accuracy-score'].mean()
clean_svm_min = clean_svm_results['accuracy-score'].min()
clean_svm_max = clean_svm_results['accuracy-score'].max()

clean_svmb_mean = clean_svm_results['balanced-accuracy-score'].mean()
clean_svmb_min = clean_svm_results['balanced-accuracy-score'].min()
clean_svmb_max = clean_svm_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {clean_svm_mean}, Min: {clean_svm_min}, Max: {clean_svm_max}')
print(f'Experiment Stats -- Mean: {clean_svmb_mean}, Min: {clean_svmb_min}, Max: {clean_svmb_max}')
# Out:
# Experiment Stats -- Mean: 68.47076923076924, Min: 49.4, Max: 75.42
# Experiment Stats -- Mean: 60.90384615384615, Min: 50.3, Max: 70.4

# %%
clean_opt_svm_results = clean_svm_results[clean_svm_results['optimized']==True]
clean_opt_svm_results
# Out:
#     workflow-number classification-algorithm algorithm-component  \
# 4                 9                      SVM        hypertangent
# 8                33                      SVM          polynomial
# 9                39                      SVM          polynomial
# 11               51                      SVM          polynomial
# 15               75                      SVM                 rbf
#
#    partition-component Imputation-component scaling-component  accuracy-score  \
# 4      random-absolute                 mean           z-score           63.84
# 8      random-absolute                 mean           z-score           67.64
# 9      random-relative                 mean           z-score           71.51
# 11      first-relative                 mean           z-score           72.63
# 15      first-relative                 mean           z-score           64.25
#
#     balanced-accuracy-score  f1-score-survived  optimized
# 4                      57.6               39.1       True
# 8                      64.2               54.0       True
# 9                      68.0               57.1       True
# 11                     68.6               58.8       True
# 15                     50.3                3.0       True

# %%
clean_opt_svm_mean = clean_opt_svm_results['accuracy-score'].mean()
clean_opt_svm_min = clean_opt_svm_results['accuracy-score'].min()
clean_opt_svm_max = clean_opt_svm_results['accuracy-score'].max()

clean_optb_svm_mean = clean_opt_svm_results['balanced-accuracy-score'].mean()
clean_optb_svm_min = clean_opt_svm_results['balanced-accuracy-score'].min()
clean_optb_svm_max = clean_opt_svm_results['balanced-accuracy-score'].max()

print(f'Experiment Stats -- Mean: {clean_opt_svm_mean}, Min: {clean_opt_svm_min}, Max: {clean_opt_svm_max}')
print(f'Experiment Stats -- Mean: {clean_optb_svm_mean}, Min: {clean_optb_svm_min}, Max: {clean_optb_svm_max}')
# Out:
# Experiment Stats -- Mean: 67.974, Min: 63.84, Max: 72.63
# Experiment Stats -- Mean: 61.739999999999995, Min: 50.3, Max: 68.6

# %% [markdown]
# # Boxplots
